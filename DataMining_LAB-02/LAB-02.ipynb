# %% [markdown]
# ##                                                        DATA MINING LAB 02
#
# ## NAME: Dinky Mishra
# ## CSUID: 2864923

# %% [markdown]
# Part1:
# 1.We want to count only the words appeared in the Webpage Text as the Content of the page, not the words included inside any tags <……> or any system generated scripts or html codes. You can count the words appeared in the title bar as well as in the Menu in the webpage
# 2. We do not want to count any subexpressions that are a part of another words.
# “Spin” should not be counted as “pin”
# 3. However, No case sensitive: Insert, insert, INSERT, insert are all counted as a same word.
# 4. The words from a same stem are counted as a same word. For example, program, programming, programed, programmable are all counted as “program”. You can directly add OR conditions with all the variations of the words that are from a same stem to count all as a same word.
# 5. We want to count for a phrase (bi-grams or tri-grams) by counting occurring of ‘data mining’, for example, when ‘data’ immediately followed by ‘mining’. This is usually done to add a discovered bi-gram or tri-gram in the term dictionary as a single term, for example, ‘data mining’ is added as a single term with ‘data_mining’ in the term dictionary with its frequency.

# %% [markdown]
# Summary of Lab2
# Fetching the Content of the Webpages:
#
# We started by retrieving the content from the given webpages. For this task, Python libraries such as requests or web scraping tools like BeautifulSoup from bs4 were utilized.
#
# Text Preprocessing:
#
# After obtaining the content, we proceeded to preprocess the text to make it suitable for analysis.
# This involved: Stripping off any HTML tags to extract only the readable text present on the webpage.
# Converting the entire content to lowercase to maintain consistency.
# Eradicating special characters and punctuation marks.
# Breaking down the content into individual words or tokens, a process called tokenization.
# Counting Term Frequencies:
#
# The next phase involved analyzing the frequency of the seven terms provided in the assignment: "research", "data", "mining", "analytics", "machine learning", "deep learning", and the bi-grams.
# It's crucial to note that bi-grams were treated as individual terms, thus requiring their frequencies to be counted as a singular term.
# Constructing Document Vectors:
#
# Finally, for each document, we crafted a vector. Each vector's entry was mapped to the frequency of one of the seven terms, allowing us to represent the content of the document in terms of these term frequencies.

# %% [markdown]
# STEP 1 : Import necessary libraries & Mount Drive

# %%
import pandas as pd
import re
import math
from collections import defaultdict

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
ls "/content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs"
# Out:
# doc1.txt  doc2.txt  doc3.txt  doc4.txt  doc5.txt  doc6.txt

# %% [markdown]
# Step 2: Define Terms and File Paths

# %%
# Terms to search for
terms = ["research", "data", "mining", "analytics", "machine learning", "deep learning", "data mining"]

# Paths to your saved text documents on Google Drive
folder_path = "/content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/"
file_names = [f"{folder_path}doc{i}.txt" for i in range(1, 7)]

# %% [markdown]
# Step 3: Read and Compute Term Frequencies for Each Document

# %%
# Dictionary to store term frequencies for each document
term_freq = defaultdict(dict)

# Read and process content for each file
for file_name in file_names:
    with open(file_name, 'r') as f:
        text = f.read().lower()  # Convert to lowercase

    # Tokenize the text (split into words)
    tokens = re.findall(r'\b\w+\b', text)

    # Count term frequencies without considering subexpressions
    for term in terms:
        term_count = 0
        for token in tokens:
            if token == term:
                term_count += 1
        term_freq[file_name][term] = term_count

# %%
# Read and process content for each file
for file_name in file_names:
    with open(file_name, 'r') as f:
        original_text = f.read()
        print(f"Original snippet for {file_name}:\n{original_text[:100]}...")  # Print the first 100 characters

        text = original_text.lower()
        print(f"Lowercase snippet for {file_name}:\n{text[:100]}...\n")  # Print the first 100 characters in lowercase
# Out:
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc1.txt:
# <!DOCTYPE html><html lang="en"><head>
#       <script type="text/javascript" data-source="https://cdn....
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc1.txt:
# <!doctype html><html lang="en"><head>
#       <script type="text/javascript" data-source="https://cdn....
#
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc2.txt:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc2.txt:
# <!doctype html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
#
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc3.txt:
# <!DOCTYPE html>
# <!-- saved from url=(0039)https://my.clevelandclinic.org/research -->
# <html lang="en...
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc3.txt:
# <!doctype html>
# <!-- saved from url=(0039)https://my.clevelandclinic.org/research -->
# <html lang="en...
#
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc4.txt:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc4.txt:
# <!doctype html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
#
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc5.txt:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc5.txt:
# <!doctype html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la...
#
# Original snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc6.txt:
#
# <!DOCTYPE html>
#
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Co...
# Lowercase snippet for /content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/doc6.txt:
#
# <!doctype html>
#
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-co...

# %% [markdown]
# Step 4: Calculate Document Frequency (DF) and Inverse Document Frequency (IDF) for Each Term

# %%
# Calculate Document Frequency (DF) for each term
df = {}
for term in terms:
    df[term] = sum(1 for doc in term_freq if term_freq[doc][term] > 0)

# Calculate Inverse Document Frequency (IDF) for each term
idf = {}
total_docs = len(file_names)
for term, freq in df.items():
    if freq == 0:
        idf[term] = 0
    else:
        idf[term] = math.log(total_docs / freq)

# %%
df
# Out:
# {'research': 6,
#  'data': 6,
#  'mining': 4,
#  'analytics': 5,
#  'machine learning': 0,
#  'deep learning': 0,
#  'data mining': 0}

# %%
idf
# Out:
# {'research': 0.0,
#  'data': 0.0,
#  'mining': 0.4054651081081644,
#  'analytics': 0.1823215567939546,
#  'machine learning': 0,
#  'deep learning': 0,
#  'data mining': 0}

# %% [markdown]
# Step 5: Calculate TF-IDF for Each Term in Each Document

# %%
# Calculate TF-IDF for each term in each document
tf_idf = {}
for doc, frequencies in term_freq.items():
    tf_idf[doc] = {}
    for term, freq in frequencies.items():
        tf_idf[doc][term] = freq * idf[term]

# %% [markdown]
# Step 6: Build the Inverted Index (Term Dictionary)

# %%
# Build Inverted Index (Term Dictionary)
inverted_index = {}
for term in terms:
    inverted_index[term] = {}
    for doc in tf_idf:
        if tf_idf[doc][term] > 0:
            inverted_index[term][doc] = tf_idf[doc][term]

# %% [markdown]
# Step 7: Display the Inverted Index

# %%
# Create a DataFrame from the Inverted Index
data = []
for term, docs in inverted_index.items():
    for doc, score in docs.items():
        data.append([term, doc, score])

df_display = pd.DataFrame(data, columns=["Term", "Document", "TF-IDF Score"])
display(df_display)
# Out:
#         Term                                           Document  TF-IDF Score
# 0     mining  /content/drive/MyDrive/Colab Notebooks/datamin...      8.514767
# 1     mining  /content/drive/MyDrive/Colab Notebooks/datamin...    113.530230
# 2     mining  /content/drive/MyDrive/Colab Notebooks/datamin...    113.530230
# 3     mining  /content/drive/MyDrive/Colab Notebooks/datamin...      2.027326
# 4  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...      8.022148
# 5  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...      0.182322
# 6  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...      3.464110
# 7  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...      3.464110
# 8  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...      4.193396

# %% [markdown]
# ##Extra Credit:Inverted Index (Term Dictionary) Construction with TF-IDF for a Full Feature Set for Each Document

# %%
import re
from collections import defaultdict

# Step 1: Import necessary libraries & Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Step 2: Define File Paths
folder_path = "/content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/"
file_names = [f"{folder_path}doc{i}.txt" for i in range(1, 7)]

# Step 3: Read and Compute Term Frequencies for Each Document
doc_term_counts = {}

for file_name in file_names:
    with open(file_name, 'r') as f:
        text = f.read().lower()  # Convert to lowercase

    tokens = re.findall(r'\b\w+\b', text)
    term_counts = defaultdict(int)
    for token in tokens:
        term_counts[token] += 1

    doc_name = file_name.split('/')[-1]  # Extract document name from file path
    doc_term_counts[doc_name] = term_counts

# Step 4: Display Unique Terms and Their Counts for Each Document
for doc_name, term_counts in doc_term_counts.items():
    print(f"\nUnique Terms and Their Counts for {doc_name}:")
    unique_terms = sorted(term_counts.items(), key=lambda x: x)  # Sort by term
    for term, count in unique_terms:
        print(f"{term}: {count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 390: 1
# 390px: 1
# 397: 2
# 3a: 41
# 3a14967969: 1
# 3a3: 1
# 3a6487637: 1
# 3abook: 17
# 3adata: 32
# 3adoi: 5
# 3aits: 1
# 3ajournal: 15
# 3akev: 32
# 3amtx: 32
# 3aoclcnum: 2
# 3aofi: 32
# 3apmid: 1
# 3asid: 32
# 3d2: 3
# 3d5: 1
# 3d546782: 1
# 3d7: 1
# 3da18c5b92: 1
# 3deng_datamininganalysis: 1
# 3djstor: 1
# 3ds2cid: 2
# 3dssrn: 1
# 3dtop_venues: 1
# 3em: 6
# 3f: 2
# 3fabstract_id: 1
# 3fg: 1
# 3fsearchdomain: 1
# 3fview_op: 1
# 3fvolume: 1
# 3px: 4
# 3rd: 2
# 4: 24
# 40: 6
# 400: 2
# 407: 2
# 41: 9
# 410: 1
# 42253: 3
# 43: 2
# 4398: 4
# 44: 2
# 440px: 1
# 4428654: 1
# 448: 2
# 4503: 4
# 451120: 2
# 45263753: 2
# 45px: 1
# 461: 4
# 47: 4
# 471: 4
# 48: 4
# 489: 4
# 49: 2
# 4a: 6
# 4c: 1
# 4d1d: 3
# 4eea: 1
# 4em: 23
# 4px: 1
# 4th: 1
# 5: 28
# 50: 4
# 500: 2
# 50000: 1
# 5000000: 2
# 50055336: 2
# 500px: 1
# 50px: 1
# 51: 5
# 512: 2
# 520: 1
# 521: 3
# 52428800: 2
# 540: 3
# 54264d1c4647: 3
# 546782: 2
# 55860: 4
# 5670: 2
# 585px: 1
# 59749: 3
# 59904: 3
# 59px: 1
# 5a20: 3
# 5dbd98ca: 2
# 5em: 13
# 5x: 12
# 6: 23
# 60: 5
# 6069: 4
# 619: 2
# 640: 1
# 640px: 1
# 6487637: 2
# 649: 1
# 65: 3
# 66: 4
# 66676dd79b: 2
# 68: 2
# 696: 2
# 6em: 4
# 7: 20
# 720px: 4
# 729: 2
# 743980: 3
# 744: 2
# 74c9c68f5f: 1
# 75px: 1
# 780px: 1
# 7cext: 4
# 7cjquery: 1
# 7cskins: 1
# 7cwikibase: 1
# 7em: 1
# 8: 14
# 80: 33
# 800: 1
# 800px: 1
# 81: 5
# 8125em: 1
# 81_: 1
# 82: 8
# 8226: 1
# 82_: 1
# 83: 7
# 83657: 3
# 84: 3
# 85: 6
# 85278: 4
# 86: 5
# 866: 1
# 87: 9
# 87u: 1
# 88: 44
# 8801055: 2
# 883: 1
# 8889: 3
# 89: 4
# 8a: 5
# 8a_: 1
# 8b: 3
# 8c: 5
# 8c_: 1
# 8d: 11
# 8e: 4
# 8em: 2
# 8f: 1
# 8f_: 2
# 9: 25
# 90: 7
# 91: 49
# 919: 2
# 92: 2
# 93: 53
# 93action: 2
# 93activity_relationship: 1
# 93chervonenkis_theory: 1
# 93computer_interaction: 1
# 93e: 1
# 93maximization_algorithm: 1
# 93reward: 1
# 93state: 1
# 93variance_tradeoff: 1
# 94: 2
# 942: 2
# 95: 10
# 95284: 3
# 96: 9
# 97: 3
# 974: 1
# 978: 40
# 98: 5
# 987007556562405171: 1
# 99: 7
# 99tin: 1
# 9a: 2
# 9b: 1
# 9be_din_date: 1
# 9d: 3
# 9e: 2
# 9em: 3
# 9f: 3
# 9f_: 1
# 9fi: 1
# 9gpfn: 2
# 9px: 3
# _chip2007: 1
# _eibehall: 2
# _friedman: 2
# _geoffrey2010: 1
# _ian_h: 1
# _kim_a: 1
# _load: 4
# _mark_a: 2
# _piatetsky: 1
# _remco_r: 1
# _spelling_bee_spiders: 7
# _transform: 4
# _william2005: 1
# _witten: 3
# _yu: 1
# a: 2364
# a0: 2
# a098: 3
# a1: 7
# a18c5b92: 2
# a1_anal: 1
# a1_d: 1
# a1ny: 1
# a1szat: 1
# a1t: 1
# a2: 2
# a2a9b1: 1
# a3: 4
# a3095046a88e: 3
# a3o_de_dados: 1
# a4: 25
# a4_: 1
# a4ck: 1
# a5: 3
# a6: 19
# a6dia: 1
# a7: 12
# a8: 11
# a8_: 1
# a9: 3
# a9es: 1
# a_priori_probability: 1
# aa: 5
# aa_: 1
# aaa: 19
# aahc: 1
# ab: 2
# ab_: 1
# ab_dh: 1
# abbr: 26
# ability: 1
# able: 3
# abnave: 1
# about: 15
# aboutsite: 1
# above: 2
# abovebelow: 7
# abs: 1
# absolute: 1
# abstract_id: 1
# ac: 3
# academic: 15
# academic_journal: 1
# academic_press: 1
# acceleration: 2
# acceptable: 1
# access: 5
# accessdate: 17
# accessibility: 2
# accesskey: 20
# according: 2
# account: 4
# accountability: 2
# accuracy: 1
# accurate: 1
# acm: 14
# acm_1: 6
# acm_computing_classification_system: 1
# across: 1
# act: 5
# action: 49
# actions: 2
# active: 3
# active_learning_: 1
# activity: 2
# actual: 3
# actually: 2
# ad: 3
# ada_de_datos: 1
# adatb: 1
# adatbányászat: 1
# add: 1
# added: 2
# additional: 2
# address: 2
# addressed: 1
# addresses: 1
# admin: 3
# advanced: 1
# adversarial: 1
# advise: 3
# ae: 12
# af: 6
# af_li: 1
# after: 19
# against: 2
# agency: 4
# agent: 4
# agent_mining: 1
# agent_reinforcement_learning: 1
# aggregate: 3
# aggregate_: 1
# aggregate_function: 1
# aggregating: 1
# aggregation: 5
# agree: 1
# agreement: 3
# ai: 1
# aid: 2
# aided: 1
# aimag: 2
# albanian: 1
# aldershot: 2
# aleph: 1
# alert: 2
# alessandro: 1
# algorithm: 15
# algorithm_design: 1
# algorithmic: 2
# algorithmic_efficiency: 1
# algorithms: 17
# aliases: 1
# align: 27
# all: 7
# all_articles_with_specifically_marked_weasel: 1
# allow: 3
# allowing: 2
# allows: 1
# alpha: 4
# also: 16
# alt: 15
# alternate: 3
# although: 1
# amazon: 5
# amazon_sagemaker: 1
# amend: 1
# america: 1
# american: 1
# among: 1
# amount: 1
# amounts: 1
# amp: 427
# amstat: 3
# an: 28
# analiza: 1
# analiza_podataka: 1
# analysis: 68
# analysis_of_algorithms: 1
# analytical: 1
# analytics: 19
# analyze: 1
# analyzing: 4
# analýza: 1
# anchor: 2
# anchor_modeling: 1
# and: 214
# andmekaeve: 2
# angoss: 3
# animation: 2
# annual: 1
# anomaly: 11
# anomaly_detection: 6
# anon: 2
# anoncontribs: 1
# anontalk: 1
# anonymity: 1
# anonymization: 1
# anonymized: 1
# anonymous: 3
# another: 2
# antonelli: 1
# any: 6
# anyone: 1
# aol: 2
# api: 3
# apparent: 1
# apparently: 1
# appear: 1
# appeared: 1
# apple: 2
# applicable: 1
# application: 12
# application_security: 1
# applications: 14
# applied: 11
# applied_data_mining: 2
# applied_statistics: 1
# applies: 1
# apply: 2
# applying: 1
# apprenticeship: 2
# apprenticeship_learning: 1
# approach: 2
# appropriate: 1
# appropriately: 1
# approximately: 1
# april: 5
# ar: 4
# arabic: 1
# archaeology: 3
# archick: 2
# architecture: 8
# archive: 33
# archived: 32
# are: 18
# areas: 1
# arena: 1
# argument: 1
# aria: 40
# arise: 1
# arizona: 1
# armenian: 1
# around: 1
# arriving: 2
# arriving_fact: 1
# art: 3
# art_24_d: 2
# article: 24
# articles: 33
# articles_with_curlie_links: 1
# articles_with_gnd_identifiers: 1
# articles_with_j9u_identifiers: 1
# articles_with_lccn_identifiers: 1
# articles_with_ndl_identifiers: 1
# articles_with_nkc_identifiers: 1
# articles_with_short_description: 1
# articles_with_specifically_marked_weasel: 1
# artificial: 19
# artificial_intelligence: 3
# artificial_neural_network: 3
# as: 45
# asa: 2
# aside: 1
# aspects: 1
# aspx: 3
# assamese: 1
# assembled: 1
# associated: 3
# association: 15
# association_for_computing_machinery: 2
# association_rule_learning: 3
# association_rule_mining: 1
# async: 10
# at: 22
# atitle: 17
# atom: 3
# attempt: 1
# attempts: 2
# attribution: 2
# au: 27
# audio: 1
# aufirst: 20
# augmentation: 2
# augmented: 1
# august: 8
# aulast: 20
# aut: 1
# auth: 1
# author: 1
# authorities: 1
# authority: 3
# authority_control: 1
# auto: 3
# autocapitalize: 1
# autocollapse: 2
# autoencoder: 3
# automata: 2
# automata_theory: 1
# automated: 5
# automated_machine_learning: 1
# automated_planning_and_scheduling: 1
# automatic: 7
# automatic_number_plate_recognition_in_the_united_kingdom: 1
# automatic_summarization: 1
# automation: 5
# automl: 1
# autostart: 1
# available: 8
# average: 1
# avoid: 6
# aware: 1
# awareness: 2
# az: 4
# azerbaijani: 1
# azevedo: 2
# azevedosantos: 2
# azevedosantos_19: 2
# azərbaycanca: 1
# b: 126
# b0: 15
# b0_: 2
# b1: 6
# b2: 19
# b3: 4
# b4: 21
# b5: 11
# b5_: 1
# b6: 3
# b6_: 1
# b6d0: 1
# b6nnb: 1
# b7: 3
# b7_: 1
# b8: 22
# b9: 3
# ba: 3
# babkov: 1
# background: 49
# backlink: 41
# bad: 1
# badge: 3
# bagging: 1
# bahasa: 2
# bangla: 1
# bas: 1
# based: 8
# based_machine_learning: 1
# bases: 2
# basket: 1
# basque: 1
# batch: 2
# batch_learning: 1
# bayes: 6
# bayesian: 3
# bayesian_network: 2
# bb: 3
# bc: 4
# bc21: 3
# bcnnemann: 1
# bd: 12
# bdi: 16
# bdza_d: 1
# be: 51
# be_: 5
# bearing: 1
# became: 2
# because: 3
# become: 1
# becomes: 1
# bee: 1
# been: 9
# before: 20
# behavior: 5
# behavior_informatics: 1
# being: 3
# beivanje_podataka: 1
# belong: 1
# below: 2
# bernhard: 2
# best: 1
# between: 4
# bf: 7
# bg: 4
# biannual: 1
# bias: 3
# big: 9
# big_data: 2
# bill: 2
# bill_inmon: 1
# bing: 2
# bing_liu_: 1
# bioinformatics: 3
# biology: 2
# biomedical: 1
# biomedicine: 1
# biotech: 3
# birch: 3
# bitness: 1
# block: 4
# blogs: 1
# bn: 4
# board: 2
# boca: 2
# bodily: 1
# body: 10
# bodycontent: 2
# bokmål: 2
# bold: 5
# boltzmann: 2
# book: 17
# bookitem: 2
# books: 3
# booksources: 32
# boosting: 2
# boosting_: 1
# bootstrap: 2
# bootstrap_aggregating: 1
# border: 50
# bot: 1
# both: 3
# bottom: 10
# bouckaert: 2
# bought: 1
# box: 35
# boxtext: 1
# br: 3
# bracket: 44
# brackets: 2
# brands: 1
# break: 7
# bridges: 1
# brief: 3
# britannica: 5
# brittanica: 2
# brittanica_2: 2
# browser: 1
# browsing: 1
# btitle: 17
# btn: 5
# build: 2
# bulgarian: 1
# burmese: 1
# bus: 2
# business: 22
# business_intelligence: 3
# business_intelligence_software: 1
# businesses: 1
# but: 7
# button: 123
# buttons: 1
# buzzword: 3
# by: 41
# bytes: 4
# c: 14
# c13_en: 1
# c3: 17
# c4: 2
# c491: 3
# c5: 1
# c8: 2
# ca: 12
# cabena: 1
# cache: 2
# cached: 1
# cachereport: 1
# cactions: 2
# called: 1
# calls: 1
# cambridge: 8
# cambridge_university_press: 1
# campaign: 2
# campaigns: 1
# can: 16
# canary: 2
# cannot: 1
# canonical: 3
# canonical_correlation: 1
# cantonese: 1
# capitalism: 2
# caps: 1
# caption: 2
# carrot2: 3
# case: 1
# cases: 2
# catalan: 1
# català: 1
# categories: 2
# category: 53
# catlinks: 6
# cats: 1
# cause: 2
# caused: 1
# cc: 2
# cca: 1
# ccf: 1
# ccl_term: 1
# cdx: 70
# ce: 12
# center: 25
# central: 1
# centralauth: 2
# centralautologin: 2
# centralnotice: 3
# centuries: 1
# certain: 2
# cf: 4
# cfm: 5
# cgi: 3
# ch: 3
# change: 9
# changed: 1
# changes: 4
# changing: 2
# characteristic: 1
# charemza: 2
# charinsert: 1
# charset: 1
# checkbox: 28
# checkuser: 1
# chemical: 3
# chemicalize: 3
# chemistry: 2
# chen: 1
# chen_tkde96: 2
# chervonenkis: 1
# child: 24
# chinese: 2
# chip: 4
# chris: 2
# christopher: 2
# ci0342472: 1
# cikm: 2
# cikm_conference: 1
# circuit: 4
# citation: 40
# citations: 2
# cite: 114
# cite_note: 88
# cite_ref: 94
# cite_web: 2
# citerefbouckaert: 1
# citerefcharemzadeadman1992: 1
# citerefclifton2010: 1
# citerefcoenen2011: 1
# citereffayyadpiatetsky: 1
# citerefgünnemannkremerseidl2011: 1
# citerefhankamber2001: 1
# citerefhankamberpei2011: 1
# citerefhastietibshiranifriedman2009: 1
# citerefhawkins2004: 1
# citerefkantardzic2003: 1
# citerefkshetri2014: 1
# citereflovell1983: 1
# citerefmena2011: 1
# citerefmurphy2011: 1
# citerefohm: 1
# citerefparker2018: 1
# citerefpiatetsky: 1
# citerefpitts: 1
# citerefresig: 1
# citerefseltzer: 1
# citereftaipale: 1
# citerefweissarchick2016: 1
# citerefwitten: 1
# citerefwittenfrankhall2011: 1
# citethispage: 1
# civil: 1
# cjeu: 1
# ckb: 4
# clandestine: 1
# class: 1221
# classes: 1
# classification: 11
# classifier: 3
# classify: 2
# classname: 5
# cleaned: 1
# cleaning: 3
# cleansing: 2
# clear: 6
# client: 7
# clienthints: 1
# clientpref: 8
# clifton: 2
# cloddio: 1
# cloddio_data: 1
# close: 1
# cloud: 2
# cluster: 11
# cluster_analysis: 7
# clustering: 11
# cn: 2
# code: 4
# code_name: 1
# codeofconduct: 1
# codex: 2
# coenen: 2
# cognitive: 2
# cognitive_computing: 1
# coined: 1
# col: 18
# coll: 3
# collapse: 6
# collapsed: 21
# collapses: 1
# collapsible: 44
# collected: 2
# collection: 8
# color: 17
# colspan: 15
# columbia: 2
# column: 19
# columns: 10
# com: 44
# combining: 1
# comes: 1
# commentedtext: 2
# commerce: 3
# commercial: 2
# commission: 4
# committees: 2
# common: 4
# commonly: 1
# commons: 49
# commons_category: 2
# commons_category_link_is_on_wikidata: 1
# communities: 2
# community: 2
# community_portal: 1
# compact: 1
# compactlinks: 1
# companies: 5
# company: 2
# compared: 1
# comparison: 3
# comparison_of_olap_servers: 1
# competition: 1
# compiled: 2
# compiler: 2
# compiler_construction: 1
# complexity: 5
# complications: 1
# component: 4
# components: 2
# comprehensible: 1
# comprehensive: 1
# compression: 4
# compromise: 1
# computability: 2
# computability_theory: 1
# computation: 4
# computational: 20
# computational_biology: 1
# computational_chemistry: 1
# computational_complexity_theory: 2
# computational_engineering: 1
# computational_geometry: 1
# computational_learning_theory: 1
# computational_mathematics: 1
# computational_physics: 1
# computational_social_science: 1
# computer: 43
# computer_accessibility: 1
# computer_animation: 1
# computer_architecture: 2
# computer_data_storage: 1
# computer_graphics: 2
# computer_hardware: 1
# computer_network: 1
# computer_retro: 7
# computer_science: 13
# computer_scientist: 1
# computer_security: 1
# computer_vision: 1
# computers: 1
# computing: 36
# computing_platform: 1
# con_lng: 1
# concept: 2
# concepts: 9
# concerns: 6
# concise: 1
# concurrency: 2
# concurrency_: 1
# concurrent: 2
# concurrent_computing: 1
# conditional: 2
# conditional_random_field: 1
# conditions: 2
# conduct: 1
# conducted: 2
# conference: 21
# conference_on_information_and_knowledge_management: 1
# conference_on_knowledge_discovery_and_data_mining: 1
# conference_on_neural_information_processing_systems: 1
# conferences: 8
# confidentiality: 3
# config: 1
# configuration: 2
# congress: 5
# congressional: 1
# connecting: 2
# connotations: 1
# consensus: 1
# consent: 2
# consequence: 1
# consequently: 1
# considerations: 2
# considered: 1
# construction: 3
# consumer: 2
# consumers: 1
# consumption: 1
# contact: 4
# contact_us: 2
# contactpage: 1
# contain: 2
# container: 34
# containing: 2
# content: 129
# contentinfo: 1
# contents: 14
# contentsub: 1
# context: 1
# contexts: 1
# contractual: 1
# contrast: 1
# contribute: 1
# contributions: 1
# contributors: 1
# control: 9
# control_theory: 1
# control_variable_: 1
# controlled: 1
# controls: 6
# convolutional: 2
# convolutional_neural_network: 1
# cookie: 5
# cookie_statement: 1
# cookiestatement: 1
# copyright: 22
# copyright_law: 5
# copyright_law_of_the_european_union: 1
# copyright_law_of_the_united_states: 1
# copyrightico: 1
# core: 2
# corporate: 1
# corporate_information_factory: 1
# corporation: 2
# corporations: 1
# corpusid: 2
# correct: 1
# correctly: 1
# correlation: 1
# corruption: 2
# count: 4
# counter: 4
# countries: 1
# country: 1
# course: 2
# court: 1
# court_of_justice_of_the_european_union: 1
# cover: 1
# covers: 2
# cpu: 1
# cputime: 1
# crc: 2
# create: 4
# createaccount: 4
# creating: 3
# creating_a_data_warehouse: 1
# creative: 1
# creativecommons: 1
# crisp: 7
# critical: 1
# croatian: 2
# cross: 10
# cross_industry_standard_process_for_data_mining: 1
# crowdsourcing: 3
# crsreports: 2
# cryptocurrency: 4
# cryptography: 3
# cs: 7
# cs1: 55
# csrftoken: 1
# ct: 2
# ctx_ver: 32
# cube: 2
# cunoștințe: 1
# curation: 2
# cure: 2
# cure_algorithm: 1
# curlie: 11
# current: 2
# current_events: 1
# currentevents: 1
# currently: 3
# curriculum: 4
# cursor: 2
# curve: 2
# curves: 1
# custom: 4
# customer: 3
# customer_analytics: 1
# customers: 3
# cx: 2
# cy: 4
# cyberwarfare: 3
# cymraeg: 1
# cz: 1
# czech: 2
# d: 5
# d0: 50
# d1: 12
# d3: 1
# d33: 2
# d5: 15
# d6: 2
# d7: 18
# d8: 17
# d9: 13
# da: 8
# dades: 1
# dados: 1
# dan: 2
# dan_linstedt: 1
# danish: 1
# dansk: 1
# danych: 1
# dark: 2
# dashboard: 2
# dashboard_: 1
# dat: 1
# data: 575
# data_: 1
# data_aggregation: 1
# data_analysis: 4
# data_and_information_visualization: 1
# data_anonymization: 1
# data_archaeology: 1
# data_augmentation: 1
# data_cleaning: 1
# data_cleansing: 1
# data_collection: 2
# data_compression: 1
# data_corruption: 1
# data_curation: 1
# data_degradation: 1
# data_dictionary: 1
# data_dredging: 2
# data_editing: 1
# data_extraction: 2
# data_farming: 1
# data_format_management: 1
# data_fusion: 1
# data_hub: 1
# data_integration: 2
# data_integrity: 1
# data_library: 1
# data_lineage: 1
# data_loading: 2
# data_loss: 1
# data_management: 3
# data_mart: 2
# data_mesh: 1
# data_migration: 1
# data_mining: 68
# data_mining_and_machine_learning_software: 1
# data_mining_and_profiling: 1
# data_mining_approach: 1
# data_mining_course: 2
# data_mining_extensions: 1
# data_mining_methodology: 4
# data_philanthropy: 1
# data_pre: 2
# data_preservation: 1
# data_privacy: 1
# data_processing: 1
# data_publishing: 1
# data_quality: 1
# data_recovery: 1
# data_reduction: 1
# data_retention: 1
# data_science: 1
# data_scraping: 2
# data_scrubbing: 1
# data_security: 1
# data_set: 2
# data_snooping: 1
# data_steward: 1
# data_storage: 1
# data_synchronization: 1
# data_transformation: 3
# data_validation: 1
# data_vault_modeling: 1
# data_warehouse: 9
# data_warehouse_automation: 1
# data_warehouses: 5
# data_warehousing_products: 1
# data_wrangling: 1
# database: 26
# database_directive: 2
# database_management: 1
# database_system: 1
# databases: 10
# datadvance: 3
# datamining: 4
# dataminingconcep0000kant: 1
# dataset: 1
# datasets: 5
# datautvinning: 4
# date: 26
# datemodified: 1
# datepublished: 1
# datizrace: 2
# datos: 1
# datu: 2
# db: 5
# dbms: 2
# dbscan: 3
# dd: 17
# ddd: 14
# ddf: 1
# de: 12
# deadman: 2
# december: 3
# decimal: 1
# decision: 19
# decision_rules: 1
# decision_support_system: 5
# decision_tree: 1
# decision_tree_learning: 2
# decoding: 9
# decomposition: 1
# decoration: 2
# deducible: 1
# deduplicate: 13
# deduplicated: 65
# deed: 1
# deep: 4
# deep_learning: 2
# deepdream: 3
# default: 2
# define: 1
# defined: 1
# defines: 1
# definition: 2
# degenerate: 2
# degenerate_dimension: 1
# degradation: 2
# density: 2
# density_estimation: 1
# dependability: 3
# dependencies: 1
# dependency: 2
# dependency_: 1
# deployment: 4
# depth: 3
# derek: 2
# derivatives: 1
# description: 10
# design: 10
# desired: 3
# desktoparticletarget: 3
# detail: 2
# details: 1
# detection: 16
# determine: 1
# deutsch: 1
# developed: 3
# developer: 1
# developers: 2
# development: 7
# deviation: 1
# dhënave: 1
# diagnostics: 1
# dialogue: 6
# dictionary: 3
# diego: 2
# difference: 3
# different: 4
# diffusion: 2
# diffusion_model: 1
# dig: 1
# digital: 8
# digital_art: 1
# digital_library: 1
# digital_marketing: 1
# digitization: 2
# dimension: 8
# dimension_: 1
# dimension_table: 1
# dimensional: 2
# dimensional_modeling: 1
# dimensionality: 3
# dimensionality_reduction: 2
# din: 1
# dir: 3
# direct: 1
# directions: 2
# directive: 5
# disabled: 16
# disclaimers: 2
# disclosure: 2
# discovered: 2
# discoveries: 1
# discovering: 5
# discovery: 24
# discrete: 2
# discrete_mathematics: 1
# discriminant: 1
# discuss: 5
# discussion: 4
# display: 15
# displayabstract: 2
# displayed: 1
# distinguish: 1
# distributed: 5
# distributed_artificial_intelligence: 1
# distributed_computing: 1
# distributed_stochastic_neighbor_embedding: 1
# div: 503
# dl: 23
# dm: 9
# dmg: 2
# dmx: 1
# dmy: 1
# dns: 2
# do: 5
# dock: 1
# doctype: 1
# document: 4
# document_management_system: 1
# documentelement: 1
# documents: 4
# does: 5
# doi: 21
# doi_: 7
# dolování: 1
# domain: 5
# domain_driven_data_mining: 1
# domains: 1
# domestic: 4
# don: 4
# donate: 3
# donating: 1
# données: 1
# dont_build_a_database_of_ruin: 1
# dots: 2
# dotted: 4
# douglas: 2
# down: 1
# download: 4
# downloadaspdf: 1
# draft: 1
# dramatically: 1
# dredging: 5
# drift: 1
# driven: 2
# dropdown: 53
# drug: 2
# drug_discovery: 1
# dss: 1
# dt: 26
# due: 2
# dutch: 1
# dát: 1
# dữ: 1
# e: 22
# e0: 96
# e1: 18
# e2: 13
# e3: 8
# e5: 1
# e6: 11
# e6e6ff: 1
# each: 1
# early: 4
# eb: 3
# ebchecked: 2
# ec: 4
# echo: 2
# echo_state_network: 1
# ecml: 2
# ecml_pkdd: 1
# econometric: 2
# economic: 3
# economics: 2
# economist: 1
# economists: 1
# ecram: 1
# ed: 4
# edit: 99
# editable: 1
# edited: 1
# editing: 3
# edition: 4
# editor: 2
# editors: 5
# editpage: 1
# edits: 2
# editsection: 66
# edituri: 1
# edu: 8
# educational: 6
# educational_data_mining: 1
# educational_technology: 1
# edward: 4
# edward_snowden: 1
# ee2e494d98bce76ebe3fe07897540c43: 1
# eesti: 1
# effective: 1
# effectively: 1
# effectiveness: 1
# efficiency: 2
# efficiently: 1
# efforts: 2
# eibe: 6
# eksploracja: 1
# eksploracja_danych: 1
# el: 4
# elder: 1
# electrochemical: 2
# electrochemical_ram: 1
# electronic: 8
# electronic_design_automation: 1
# electronic_discovery: 1
# electronic_publishing: 1
# electronic_voting: 1
# element: 15
# elements: 6
# elements_3: 2
# elemstatlearn: 2
# elgar: 2
# eli: 2
# elki: 3
# ellipsis: 2
# elsevier: 5
# elt: 3
# em: 1
# embedded: 2
# embedded_system: 1
# embedding: 1
# emotional: 1
# empirical: 2
# empirical_risk_minimization: 1
# empty: 2
# emptyportlet: 3
# en: 53
# enable: 1
# enabled: 12
# encouraged: 4
# encyclop: 1
# encyclopedia: 2
# encyclopædia: 1
# end: 5
# energy: 1
# enforcement: 4
# eng: 1
# eng_datamininganalysis: 2
# engine: 1
# engineering: 14
# english: 5
# enhancements: 1
# enough: 3
# ensemble: 4
# ensemble_learning: 2
# ensembles: 1
# entered: 1
# enterprise: 7
# enterprise_bus_matrix: 1
# enterprise_information_system: 1
# enterprise_software: 1
# entities: 1
# entity: 5
# entity_recognition: 1
# entityaccesscount: 1
# entitypage: 2
# entitytype: 2
# environment: 4
# enwiki: 1
# enwikimwclientpreferences: 1
# eqiad: 3
# erlbaum: 1
# error: 3
# errors: 1
# es: 4
# esi: 2
# esitest: 1
# esn: 1
# español: 1
# especially: 1
# essential: 1
# estimating: 1
# estimation: 2
# estonian: 1
# et: 4
# etc: 1
# ethical: 4
# ethics: 9
# etl: 2
# etymology: 7
# eu: 10
# europa: 3
# europe: 19
# european: 15
# european_commission: 1
# european_conference_on_machine_learning_and_principles_and_practice_of_knowledge_discovery_in_databases: 1
# european_union: 1
# euskara: 1
# evaluate: 2
# evaluation: 4
# even: 15
# event: 13
# eventlogging: 2
# events: 2
# ever: 1
# example: 9
# examples: 7
# examples_of_data_mining: 3
# exception: 3
# exceptions: 2
# exchange: 1
# exchanging: 1
# execute: 1
# exist: 4
# exists: 1
# expand: 8
# expanded: 13
# expansion: 2
# expansiondepth: 1
# expectation: 3
# expensive: 1
# expensivefunctioncount: 1
# experiences: 2
# experimentation: 1
# experiments: 1
# expiry: 2
# exploit: 2
# exploitation: 1
# exploited: 1
# exploiting: 1
# exploration: 1
# exploration_de_donn: 1
# explorations: 4
# exploratory: 2
# exploratory_data_analysis: 1
# explorer: 1
# exploring: 1
# export: 1
# expose: 1
# exposed: 1
# expression: 1
# expressions: 2
# ext: 28
# extension: 2
# extensions: 3
# external: 96
# external_links: 4
# extiw: 3
# extra: 1
# extract: 13
# extracted: 1
# extracting: 5
# extraction: 11
# extragerea: 1
# extragerea_de_cuno: 1
# f: 11
# f05_romedataqualityetc: 2
# f2a14b97: 1
# f3b8: 1
# f7f7f7: 1
# f8f9fa: 1
# f9f9f9: 1
# fa: 4
# fa8a495983347898: 1
# facilitated: 1
# facilitates: 1
# fact: 7
# fact_: 1
# fact_table: 1
# factor: 6
# factor_analysis: 2
# factorization: 1
# factory: 2
# failed: 1
# fair: 7
# fair_use: 1
# fake: 16
# fall: 1
# false: 12
# family: 2
# family_educational_rights_and_privacy_act: 1
# farming: 2
# favicon: 1
# favor: 2
# fayyad: 10
# fayyad_5: 6
# fdfdfd: 3
# feature: 31
# feature_engineering: 1
# feature_learning: 1
# february: 1
# fedlex: 5
# feed: 2
# feedforward: 2
# feedforward_neural_network: 1
# feldman: 1
# ferpa: 1
# fi: 4
# field: 5
# figcaption: 2
# figure: 2
# file: 45
# file_upload_wizard: 2
# filed: 1
# files: 5
# filling: 1
# final: 3
# final_uploads: 2
# finance: 1
# financial: 3
# find: 5
# find_code: 1
# finnish: 1
# first: 14
# firstheading: 3
# fishing: 3
# fl: 2
# flex: 4
# float: 8
# florent: 1
# flow: 1
# flush: 5
# focal: 2
# focal_point_modeling: 1
# focus: 1
# following: 3
# follows: 1
# font: 40
# footer: 27
# for: 85
# force: 1
# forcing: 1
# foreach: 1
# forensics: 2
# forest: 4
# form: 5
# formal: 7
# formal_language: 1
# formal_methods: 1
# formal_sciences: 1
# format: 14
# found: 2
# foundation: 9
# foundations: 1
# fr: 4
# frameless: 2
# framework: 8
# francis: 2
# frank: 8
# frans: 2
# français: 1
# free: 12
# free_open: 4
# french: 1
# frequently: 2
# friedman: 5
# friendly: 1
# from: 50
# frompage: 2
# ft: 3
# full: 1
# fullscreen: 2
# fullversionlist: 1
# fully: 1
# func: 2
# function: 9
# fundraiserredirector: 1
# further: 7
# further_reading: 4
# fusion: 2
# future: 5
# fuzzy: 2
# fuzzy_clustering: 1
# g: 9
# gadget: 4
# game: 1
# games: 1
# gan: 1
# gap: 1
# gary: 3
# gate: 1
# gated: 1
# gated_recurrent_unit: 1
# gather: 1
# gehomepagesuggestededitsenabletopics: 1
# general: 4
# general_architecture_for_text_engineering: 1
# general_disclaimer: 1
# generalized: 1
# generalizing: 1
# generally: 1
# generation: 1
# generative: 3
# generative_adversarial_network: 1
# generative_model: 1
# generator: 1
# genetic: 5
# genetic_algorithms: 2
# genre: 32
# geoffrey: 2
# geographic: 2
# geographic_information_system: 1
# geoip: 1
# geometry: 2
# george: 2
# german: 1
# germany: 1
# get: 1
# ghostarchive: 4
# give: 1
# given: 3
# global: 2
# global_surveillance_disclosure: 1
# global_thinking: 6
# globalcssjs: 2
# glossary: 2
# glossary_of_artificial_intelligence: 1
# gnd: 4
# gnu: 3
# gnu_project: 1
# go: 2
# goal: 3
# good: 1
# goodarticle: 1
# google: 18
# google_book_search_settlement_agreement: 1
# google_cloud_platform: 1
# google_scholar: 1
# googpub: 1
# gov: 5
# government: 4
# gpspubs: 2
# grammar: 2
# grammar_induction: 1
# grants: 2
# graphical: 2
# graphical_model: 1
# graphics: 8
# graphics_processing_unit: 1
# gray: 1
# greater: 1
# greek: 3
# green: 3
# green_computing: 1
# gregory: 16
# gregory_i: 1
# gregory_piatetsky: 6
# grossman: 1
# group: 68
# groups: 6
# grown: 1
# growthexperiments: 1
# gru: 1
# guidance: 1
# guides: 1
# guo: 1
# günnemann: 1
# h: 14
# h1: 2
# h2: 28
# h3: 18
# habits: 1
# had: 1
# hadjnian: 1
# hall: 8
# han: 13
# handbook: 3
# hands: 1
# hanging: 5
# happening: 1
# harbor: 5
# hardware: 7
# hardware_acceleration: 1
# hardware_security: 1
# hardy: 2
# hargreaves: 2
# hargreaves_review: 1
# harm: 1
# harvard: 2
# harvesting: 1
# has: 14
# haspopup: 6
# hastie: 5
# hatnote: 11
# have: 10
# hawkins: 4
# hawkins_20: 2
# hbr: 2
# he: 4
# head: 3
# header: 47
# heading: 12
# headline: 23
# health: 3
# health_informatics: 1
# health_insurance_portability_and_accountability_act: 1
# healthcare: 1
# hebrew: 1
# height: 41
# help: 10
# here: 2
# hewlett: 3
# hi: 4
# hidden: 18
# hidden_markov_model: 1
# hide: 4
# hierarchical: 2
# hierarchical_clustering: 1
# high: 3
# highest: 1
# hindi: 1
# hipaa: 5
# histories: 1
# history: 6
# hlist: 78
# hnc: 1
# holap: 3
# holmes: 3
# hor: 1
# hosted: 2
# how: 8
# however: 12
# hr: 4
# href: 1203
# hreflang: 61
# hrvatski: 1
# htm: 6
# html: 13
# http: 65
# https: 174
# hu: 4
# hub: 3
# human: 6
# humans: 1
# hungarian: 1
# hy: 4
# hyperlinks: 1
# hypotheses: 3
# hypothesis: 3
# hĺbková: 1
# i: 184
# iadis: 3
# ian: 9
# ian_h: 3
# ibm: 4
# ica: 2
# icde: 1
# iclr: 1
# icml: 1
# ico: 1
# icon: 54
# icons: 4
# id: 324
# identifiable: 2
# identification: 3
# identified: 2
# identifier: 63
# identifiers: 16
# identify: 2
# identifying: 1
# idhash: 1
# ieee: 1
# if: 3
# ijcai: 1
# il: 1
# illegal: 2
# illustration: 2
# image: 23
# image_compression: 1
# imageobject: 1
# imageright: 1
# images: 11
# img: 15
# immediately: 1
# impact: 2
# impedes: 1
# impl: 1
# implementation: 1
# implemented: 1
# implements: 1
# implications: 2
# importance: 6
# important: 7
# importantly: 1
# improvements: 1
# in: 134
# inadvertent: 1
# inadvertently: 1
# inc: 2
# include: 5
# including: 2
# incomprehensibility: 1
# increased: 2
# increasing: 1
# increasingly: 1
# increment: 1
# indent: 2
# indents: 5
# independent: 1
# independent_component_analysis: 1
# independently: 1
# index: 52
# indexed: 1
# indicated: 1
# indicates: 1
# indicators: 1
# indices: 1
# indirect: 1
# indiscretion: 1
# individual: 3
# individuals: 7
# indonesia: 1
# indonesian: 1
# induction: 2
# indurkhya: 1
# industry: 4
# industry_standard_process_for_data_mining: 1
# inference: 5
# inferences: 1
# info: 78
# informasjonsutvinning: 2
# informatics: 3
# information: 59
# information_extraction: 2
# information_integration: 1
# information_privacy: 1
# information_processing: 1
# information_retrieval: 1
# information_science: 1
# information_security: 1
# information_society_directive: 1
# information_system: 1
# information_theory: 1
# informationweek: 4
# informed: 2
# inherit: 15
# init: 3
# inline: 75
# inmon: 2
# inner: 6
# input: 14
# input__end: 1
# input__icon: 1
# input__input: 2
# input__start: 1
# inside: 6
# instance: 1
# instant: 2
# institute: 2
# insurance: 2
# integrated: 5
# integrated_circuit: 1
# integrated_development_environment: 1
# integration: 8
# integrity: 2
# intellectual: 2
# intellectual_property: 1
# intelligence: 26
# intelligent: 2
# intended: 1
# intention: 3
# intention_mining: 1
# interaction: 6
# interaction_design: 1
# interchangeably: 1
# interdisciplinary: 3
# interest: 1
# interesting: 2
# interestingness: 1
# interface: 2
# interlanguage: 125
# international: 10
# international_conference_on_learning_representations: 1
# international_conference_on_machine_learning: 1
# international_conference_on_very_large_data_bases: 1
# international_joint_conference_on_artificial_intelligence: 1
# international_journal_of_data_warehousing_and_mining: 1
# international_safe_harbor_privacy_principles: 1
# interpret: 1
# interpretation: 2
# interpreter: 2
# interpreter_: 1
# intersection: 1
# interwiki: 60
# into: 4
# intro: 3
# introduced: 1
# introduction: 8
# intrusion: 2
# intrusion_detection_system: 1
# invalidated: 1
# investigating: 1
# investigation: 1
# involves: 4
# involving: 1
# ip: 2
# ir: 2
# is: 63
# isbn: 40
# isbn_: 16
# isolation: 2
# isolation_forest: 1
# israel: 2
# issn: 4
# issn_: 1
# issue: 7
# issued: 1
# issues: 2
# istra: 1
# istraživanje: 1
# it: 28
# italian: 1
# italiano: 1
# italic: 2
# item: 144
# items: 2
# its: 8
# itself: 2
# j: 4
# j9u: 3
# ja: 4
# jaap: 1
# jaiwei: 2
# james: 1
# january: 2
# japan: 2
# japanese: 1
# java: 12
# java_: 4
# java_data_mining: 1
# jdm: 3
# jerome: 5
# jerome_h: 2
# jes: 1
# jesús: 1
# jian: 3
# jiawei: 6
# jiawei_han: 3
# jmlr: 1
# john: 5
# johnresig: 2
# joint: 1
# journal: 20
# journal_article: 1
# journal_of_machine_learning_research: 1
# journalists: 1
# journals: 3
# jp: 1
# jquery: 3
# js: 2
# jsm2005seltzer: 2
# json: 1
# jstor: 4
# jstor_: 1
# jtitle: 15
# judge: 3
# judgment: 2
# july: 1
# jump: 2
# june: 5
# justice: 1
# jvxss: 1
# k: 11
# kamber: 7
# kamber_6: 2
# kannada: 1
# kantardzic: 4
# kantardzic_16: 2
# kaufmann: 8
# kd: 1
# kdd: 17
# kdd89: 1
# kdd_conference: 1
# kdnuggets: 19
# kern: 2
# kernel: 2
# kernel_machines: 1
# key: 4
# khai: 1
# khai_ph: 1
# killed: 1
# kim: 2
# kimball: 2
# kind: 1
# kingdom: 3
# kluwer: 2
# kluwer_academic_publishers: 1
# kn: 4
# knime: 3
# knowledge: 32
# knowledge_discovery: 2
# knowledge_extraction: 1
# knowledge_management: 1
# knowledge_representation_and_reasoning: 1
# knowledgestudio: 1
# known: 4
# ko: 4
# konstantinos: 1
# konstanz: 1
# korea: 1
# korean: 1
# koutroumbas: 1
# kremer: 2
# kristin: 2
# kshetri: 2
# kumar: 1
# kurdish: 1
# kurgan: 3
# kurgan_18: 2
# l: 1
# label: 53
# labelledby: 4
# laid: 1
# landmark: 6
# lang: 74
# langlinks: 2
# language: 50
# languages: 4
# large: 14
# larger: 3
# lars: 2
# lars_r: 1
# last: 13
# lastmod: 1
# latvian: 1
# latviešu: 1
# law: 20
# law_enforcement: 1
# lawful: 2
# lawrence: 1
# laws: 5
# lawsuit: 1
# lazy: 2
# lccn: 3
# ld: 1
# lda: 1
# leading: 2
# learn: 8
# learned: 5
# learning: 147
# learning_: 1
# learning_classifier_system: 1
# learning_curve_: 1
# learning_research: 1
# learning_to_rank: 1
# least: 1
# leave: 1
# led: 2
# left: 28
# legal: 2
# legality: 2
# legislation: 2
# legitimate: 2
# lesson: 2
# level: 25
# levels: 1
# lexisnexis: 1
# lexology: 5
# li: 1415
# libereurope: 2
# libraries: 4
# library: 11
# library_: 1
# libres: 2
# licences: 5
# license: 4
# licenses: 3
# licensing: 1
# like: 1
# limit: 12
# limitation: 1
# limitations: 2
# limitations_and_exceptions_to_copyright: 1
# limited: 8
# limitreport: 3
# line: 13
# lineage: 2
# linear: 3
# linear_discriminant_analysis: 1
# linear_regression: 1
# link: 232
# linked: 1
# links: 25
# linksdir: 2
# linstedt: 2
# lion: 1
# lionsolver: 3
# list: 302
# list_of_computer_science_conferences: 1
# list_of_datasets_for_machine: 1
# list_of_datasets_in_computer_vision_and_image_processing: 1
# list_of_reporting_software: 1
# listbullet: 3
# listitem: 4
# little: 1
# liu: 2
# liệu: 1
# load: 11
# loaded: 1
# loader: 1
# loading: 5
# loc: 2
# local: 2
# local_base: 2
# local_outlier_factor: 1
# lock: 13
# log: 7
# logged: 2
# logic: 2
# logic_in_computer_science: 1
# login: 5
# logistic: 2
# logistic_regression: 1
# logo: 19
# long: 2
# long_short: 1
# longstanding: 1
# loop: 3
# loss: 2
# lovell: 5
# lower: 7
# lstm: 1
# ltd: 1
# ltr: 13
# lua: 4
# lua_: 1
# lukasz: 1
# lv: 4
# m: 7
# macedonian: 1
# machine: 98
# machine_learning: 19
# machine_learning_: 1
# machine_learning_bar: 2
# machine_learning_model: 1
# machinery: 3
# machines: 6
# made: 2
# madenciliği: 1
# magazine: 1
# maguelonne: 1
# magyar: 1
# mahwah: 1
# mail: 2
# mails: 4
# main: 42
# main_page: 2
# mainentity: 1
# mainpage: 1
# maint: 1
# maintenance: 2
# majority: 1
# make: 3
# makecollapsible: 3
# malay: 1
# malayalam: 1
# managed: 2
# management: 17
# mandatory: 4
# manipulation: 3
# manual: 2
# manual_of_style: 1
# many: 6
# map: 1
# marathi: 1
# march: 5
# margin: 46
# mark: 6
# marked: 6
# market: 2
# marketing: 7
# marketing_campaign: 1
# markov: 2
# markup: 4
# mart: 4
# martin: 2
# masquerades: 1
# mass: 2
# mass_surveillance: 1
# masseglia: 1
# massive: 2
# massive_online_analysis: 1
# match: 1
# material: 2
# mathematical: 7
# mathematical_analysis: 1
# mathematical_optimization: 1
# mathematical_software: 1
# mathematics: 5
# matrix: 2
# max: 4
# maximization: 2
# may: 16
# mdx: 1
# mean: 2
# mean_shift: 1
# means: 2
# means_clustering: 1
# measure: 2
# measure_: 1
# measured: 1
# meatzaritza: 2
# media: 10
# mediawiki: 8
# medicine: 1
# meet: 2
# meetings: 1
# megaputer: 1
# mehmed: 2
# melayu: 1
# memory: 2
# memtransistor: 3
# memusage: 1
# mena: 4
# mena_13: 2
# menu: 89
# mepx: 1
# mesh: 2
# message: 5
# message__content: 1
# message__icon: 1
# messaging: 2
# meta: 24
# metadata: 3
# method: 1
# methodology: 11
# methods: 16
# metrics: 1
# michael: 5
# michael_lovell: 1
# micheline: 5
# microsoft: 13
# microsoft_academic_search: 1
# microsoft_analysis_services: 1
# middleware: 3
# might: 5
# migration: 2
# min: 2
# mine: 1
# mined: 1
# miner: 7
# minera: 1
# mineração: 1
# mineria: 1
# mineria_de_dades: 1
# miners: 1
# minerva: 1
# minería: 1
# mini: 6
# minimi: 1
# minimi_i_t: 1
# minimization: 2
# mining: 280
# mining_software_and_applications: 4
# misnomer: 3
# missing: 2
# missing_data: 1
# misused: 1
# mixed: 2
# mixed_reality: 1
# mk: 4
# ml: 7
# mlpack: 3
# mmv: 2
# mn: 4
# moa: 2
# moa_: 1
# mobile: 4
# mobileaction: 1
# mobileview: 1
# model: 17
# model_of_computation: 1
# modeler: 2
# modeling: 18
# modeling_language: 1
# models: 14
# modified: 1
# module: 1
# modules: 3
# molap: 3
# mongolian: 1
# more: 21
# morgan: 8
# morgan_kaufmann: 2
# mostly: 1
# move: 3
# moved: 1
# mr: 4
# ms: 5
# multi: 7
# multi_expression_programming: 1
# multidimensional: 2
# multidimensional_expressions: 1
# multidisciplinary: 1
# multilinear: 2
# multilinear_subspace_learning: 1
# multilingual: 1
# multimedia: 2
# multimedia_database: 1
# multimodal: 2
# multimodal_learning: 1
# multiple: 1
# multiprocessing: 3
# multithreading: 2
# multithreading_: 1
# multivariate: 2
# multivariate_statistics: 1
# munging: 1
# murphy: 2
# musilek: 1
# must: 2
# mw: 862
# my: 4
# mycontributions: 1
# mylanguage: 3
# mytalk: 1
# n: 15
# n_kshetri_big_2014: 2
# naive: 2
# naive_bayes_classifier: 1
# name: 34
# named: 6
# namespaces: 1
# nascio: 9
# nascio_30: 6
# national: 7
# national_security: 1
# national_security_agency: 2
# natural: 7
# natural_language_processing: 2
# natural_language_toolkit: 1
# nav: 18
# navbar: 24
# navbox: 201
# navigation: 21
# navigationtiming: 1
# nb: 3
# ncbi: 1
# ndl: 4
# ndlna: 1
# near: 1
# nearby: 1
# nearest: 2
# nearest_neighbors_algorithm: 2
# necessarily: 1
# necessary: 1
# necessity: 1
# nederlands: 1
# need: 5
# negative: 2
# negative_matrix_factorization: 1
# neighbor: 1
# neighbors: 2
# neither: 1
# net: 6
# netowl: 3
# network: 32
# network_architecture: 1
# network_performance: 1
# network_protocol: 1
# network_scheduler: 1
# network_security: 1
# network_service: 1
# networking: 1
# networking_hardware: 1
# networks: 8
# neural: 21
# neural_network_with_dark_background: 14
# neural_networks: 2
# neurips: 1
# new: 17
# newly: 1
# newpp: 1
# news: 2
# nih: 1
# ning: 1
# nir: 2
# nisbet: 1
# nitin: 1
# nj: 1
# nju: 2
# nkc: 3
# nkp: 1
# nl: 4
# nli: 1
# nlm: 1
# nlp: 1
# nltk: 3
# nlx10: 1
# nmf: 1
# nn: 6
# no: 9
# nobold: 2
# node: 1
# noexcerpt: 1
# nofollow: 90
# noicon: 5
# noise: 2
# nojs: 1
# nomobile: 2
# non: 4
# none: 43
# nong: 1
# noprint: 6
# nor: 1
# normal: 9
# norsk: 2
# norwegian: 2
# noscript: 4
# nosnippet: 1
# not: 30
# notable: 4
# notable_uses: 4
# notations: 1
# note: 7
# notes: 3
# notice: 2
# november: 10
# noviewer: 6
# nowrap: 20
# nowraplinks: 11
# ns: 2
# nstab: 1
# nuggets: 1
# null: 1
# numb: 22
# number: 4
# numerical: 2
# numerical_analysis: 1
# nv: 12
# nynorsk: 2
# o: 4
# obligations: 1
# observations: 1
# obtain: 1
# occam: 2
# occam_learning: 1
# occur: 2
# occurred: 2
# oclc: 6
# oclc_: 2
# october: 3
# odd: 24
# of: 192
# offer: 1
# often: 2
# og: 11
# ohm: 2
# okairp: 3
# ol: 28
# olap: 5
# olap_cube: 1
# oldid: 3
# olson: 1
# omics: 1
# on: 73
# once: 2
# one: 2
# online: 9
# online_algorithm: 1
# online_analytical_processing: 1
# online_machine_learning: 1
# only: 20
# ontology: 2
# ontology_learning: 1
# oojs_ui_icon_edit: 6
# open: 15
# open_access: 1
# open_source_model: 1
# opennn: 3
# opensearch_desc: 1
# opensearchdescription: 1
# operated: 1
# operating: 3
# operating_system: 1
# operational: 2
# operational_data_store: 1
# operations: 2
# operations_research: 1
# opposed: 1
# optics: 2
# optics_algorithm: 1
# optimization: 3
# options: 4
# or: 24
# oracle: 4
# oracle_corporation: 1
# oracle_data_mining: 1
# orange: 2
# orange_: 1
# org: 252
# organization: 5
# organizing: 1
# organizing_map: 1
# oriented: 3
# oriented_dbms: 1
# origin: 4
# original: 21
# originally: 3
# other: 7
# otherproject: 2
# otherprojects: 2
# otherwise: 2
# out: 7
# outer: 1
# outlier: 5
# outline: 5
# outline_of_computer_science: 1
# outline_of_machine_learning: 1
# output: 198
# overall: 2
# overcome: 1
# overfitting: 8
# overflow: 2
# overridden: 1
# overview: 5
# owner: 1
# owners: 1
# p: 108
# pablo: 1
# pac: 1
# packard: 3
# padding: 116
# padhraic: 2
# page: 71
# pagelanguagecode: 1
# pagelanguagedir: 1
# pageprop: 1
# pages: 17
# pagevariantfallbacks: 1
# paid: 1
# panel: 3
# pang: 1
# papers: 2
# paradigm: 2
# paradigms: 1
# parallel: 3
# parallel_computing: 1
# parker: 4
# parsed: 1
# parser: 198
# part: 5
# particular: 6
# parts: 1
# pascal: 1
# passage: 1
# past: 4
# patroltoken: 1
# patrons: 1
# pattern: 5
# patterns: 25
# paul: 2
# pay: 1
# pca: 1
# pcache: 1
# pdf: 33
# pei: 3
# penggalian: 1
# penggalian_data: 1
# people: 4
# people_icon: 6
# per: 1
# perceptron: 3
# performance: 3
# performing: 1
# peripheral: 3
# perlombongan: 1
# perlombongan_data: 1
# permalink: 1
# permanent: 2
# permission: 1
# persian: 1
# personal: 5
# personally: 2
# personally_identifiable_information: 1
# perspective: 1
# peter: 3
# petr: 1
# pfahringer: 2
# pgd: 1
# ph165954: 1
# pharmaceutical: 1
# phases: 2
# philanthropy: 2
# philip: 1
# philip_s: 1
# philosophy: 2
# philosophy_of_artificial_intelligence: 1
# photograph: 2
# photograph_manipulation: 1
# php: 58
# phrase: 1
# phrases: 6
# physics: 2
# phá: 1
# piatetsky: 16
# pin: 6
# pinnable: 36
# pinned: 22
# pitch: 1
# pitfalls: 2
# pitts: 2
# pkdd: 2
# pl: 4
# place: 3
# placeholder: 1
# places: 11
# plainlinks: 5
# plainlist: 9
# planning: 2
# plate: 2
# platform: 7
# platformversion: 1
# play: 3
# play_: 1
# pmid: 2
# pmid_: 1
# pmml: 3
# png: 47
# podataka: 3
# podatkovno: 1
# podatkovno_rudarjenje: 1
# point: 2
# policy: 6
# polish: 1
# poll: 4
# polls: 10
# polski: 1
# polyanalyst: 3
# poncelet: 1
# popular: 2
# population: 1
# populations: 1
# popups: 1
# portability: 2
# portal: 3
# portlet: 29
# portuguese: 1
# português: 1
# position: 1
# positive: 2
# possibly: 1
# post: 3
# postexpandincludesize: 1
# potentially: 1
# power: 1
# powered: 1
# poweredby_mediawiki_132x47: 1
# poweredby_mediawiki_176x62: 1
# poweredby_mediawiki_88x31: 1
# poweredbyico: 1
# pp: 3
# ppvisitednodes: 1
# practical: 7
# practice: 7
# practices: 2
# pre: 15
# preconnect: 1
# predict: 1
# prediction: 9
# predictive: 11
# predictive_analytics: 3
# predictive_model_markup_language: 1
# pref: 3
# preferences: 2
# prefetch: 2
# premier: 1
# prentice: 2
# prentice_hall: 1
# preparation: 4
# preprocessor: 1
# prescription: 1
# present: 7
# preservation: 2
# presiding: 1
# press: 9
# pretitle: 6
# prevent: 1
# preview: 1
# previously: 1
# prices: 1
# primarily: 1
# principal: 1
# principal_component_analysis: 1
# principles: 4
# print: 2
# print_export: 2
# printable: 3
# printed: 2
# printed_circuit_board: 1
# printfooter: 1
# priori: 2
# privacy: 33
# privacy_concerns_and_ethics: 5
# privacy_policy: 2
# privacy_violation: 1
# private: 1
# probability: 4
# probably: 1
# probably_approximately_correct_learning: 1
# problem: 4
# problems: 2
# proceedings: 5
# process: 29
# process_control: 1
# processes: 1
# processing: 35
# processor: 1
# produced: 2
# producers: 1
# producing: 1
# product: 3
# productionising: 1
# products: 5
# professional: 1
# profiling: 2
# profiling_: 1
# profit: 1
# program: 2
# programming: 26
# programming_language: 10
# programming_language_theory: 1
# programming_paradigm: 1
# programming_team: 1
# programming_tool: 1
# programs: 1
# progressive: 9
# project: 8
# projects: 3
# proliferation: 1
# promise: 2
# proper: 2
# proper_generalized_decomposition: 1
# property: 14
# proposed: 1
# proprietary: 4
# proprietary_data: 4
# protected: 1
# protection: 3
# protocol: 2
# provide: 2
# provided: 8
# provider: 1
# providing: 1
# provision: 2
# pseven: 3
# pspp: 3
# psychometrics: 3
# pt: 10
# pub: 10
# public: 1
# publications: 4
# published: 4
# publisher: 1
# publishers: 3
# publishing: 4
# pubmed: 1
# purchasing: 1
# pure: 1
# purpose: 1
# purposes: 4
# push: 2
# python: 5
# python_: 2
# q: 12
# q172491: 6
# q17437798: 1
# qlucore: 3
# quality: 4
# quantitative: 2
# quantitative_structure: 1
# quantities: 1
# quantum: 2
# quantum_machine_learning: 1
# questions: 1
# quick: 1
# quiet: 12
# quotes: 1
# r: 8
# r1011085734: 1
# r1033289096: 6
# r1038841319: 2
# r1045330069: 1
# r1054258005: 1
# r1061467846: 4
# r1063604349: 4
# r1126788409: 1
# r1129693374: 9
# r1133582631: 42
# r1134653256: 1
# r1147244281: 4
# r44257: 3
# r886047488: 2
# r_: 1
# raise: 1
# raised: 1
# ralph: 2
# ralph_kimball: 1
# ram: 2
# random: 7
# random_forest: 1
# random_sample_consensus: 1
# randomized: 2
# randomized_algorithm: 1
# randomly: 1
# randompage: 1
# range: 1
# ranging: 1
# rank: 2
# ransac: 1
# rapidminer: 3
# rather: 2
# raton: 2
# raw: 2
# re: 3
# reach: 1
# reaching: 1
# read: 2
# readily: 1
# reading: 5
# reading01: 2
# ready: 18
# real: 8
# reality: 4
# reasoning: 2
# reasons: 2
# receiver: 1
# receiver_operating_characteristic: 1
# recent: 3
# recentchanges: 3
# recentchangeslinked: 2
# recognition: 5
# recommendation: 1
# recommended: 1
# records: 3
# recovery: 2
# recurrent: 3
# recurrent_neural_network: 1
# recursion: 1
# red: 1
# redirect: 120
# redirects: 1
# redlink: 3
# reduced: 1
# reduction: 6
# refbegin: 11
# refer: 2
# reference: 107
# references: 11
# referencetooltips: 1
# referred: 1
# referrer: 2
# referring: 1
# reflist: 16
# regarding: 2
# regardless: 1
# regexp: 1
# registered: 1
# registration: 4
# regression: 15
# regression_analysis: 5
# regulating: 1
# regulations: 1
# regulatory: 1
# reinforcement: 8
# reinforcement_learning: 3
# reinforcement_learning_technique: 1
# rel: 172
# related: 8
# relation: 1
# relationship: 2
# relationships: 2
# released: 1
# relevance: 2
# relevance_vector_machine: 1
# reliable: 1
# remaining: 1
# remco: 2
# removes: 1
# rendering: 3
# rendering_: 1
# repeat: 4
# replace: 2
# report: 3
# reported: 1
# reporting: 3
# repository: 2
# representation: 3
# representations: 1
# representatives: 1
# reproduced: 1
# reproducibility: 2
# republic: 1
# request: 1
# require: 2
# required: 2
# requirements: 2
# requirements_analysis: 1
# requires: 2
# research: 27
# researchers: 6
# reservoir: 2
# reservoir_computing: 1
# reset: 1
# resig: 2
# resourceloaderdynamicstyles: 1
# resources: 1
# restricted: 2
# restricted_boltzmann_machine: 1
# restriction: 1
# result: 2
# resulting: 1
# results: 7
# results_validation: 4
# retention: 2
# retrieval: 2
# retrieved: 20
# return: 1
# returnto: 4
# reutemann: 2
# revelation: 1
# reverse: 2
# reverse_star_schema: 1
# review: 14
# review_of_economic_studies: 1
# reviews: 1
# revision: 3
# revisions: 1
# revoke: 1
# reward: 1
# rfr_id: 32
# rft: 219
# rft_id: 33
# rft_val_fmt: 32
# rgba: 1
# right: 25
# rights: 5
# risk: 2
# rl: 1
# rlconf: 1
# rlpagemodules: 1
# rlq: 4
# rlstate: 1
# ro: 4
# robert: 7
# robert_tibshirani: 2
# robots: 1
# roc: 1
# rolap: 3
# role: 25
# rolf: 1
# roman: 4
# romanian: 1
# română: 1
# ronen: 1
# root: 1
# rootpage: 1
# roughly: 1
# row: 29
# rowspan: 1
# rsd: 2
# rt: 2
# ru: 4
# rudarenje: 1
# rudarenje_podataka: 1
# rudarjenje: 1
# ruin: 2
# rule: 14
# ruled: 1
# rules: 4
# russian: 1
# rvm: 1
# rönnbäck: 2
# s: 17
# s0269888906000737: 1
# s0269888910000378: 2
# s11628: 1
# s2cid: 4
# s2cid_: 2
# sa: 1
# safe: 5
# sagemaker: 2
# same: 2
# sameas: 1
# sample: 4
# san: 2
# san_diego: 1
# sanger: 1
# santos: 2
# sarsa: 1
# sas: 4
# sas_: 1
# sas_institute: 1
# saved: 1
# savvy: 1
# says: 1
# scale: 4
# scaling: 1
# scheduler: 2
# scheduling: 2
# schema: 7
# scholar: 7
# science: 32
# sciences: 5
# scientific: 2
# scientific_computing: 1
# scientist: 1
# scikit: 3
# scope: 35
# scraping: 5
# screen: 2
# scribunto: 1
# script: 10
# scripts: 1
# scrubbing: 2
# sdl: 1
# se: 1
# search: 45
# searchable: 6
# searchaux: 1
# searchdomain: 2
# searches: 1
# searchform: 1
# searchinput: 1
# second: 1
# seconds: 3
# section: 46
# security: 27
# security_service_: 1
# securityfocus: 3
# see: 9
# see_also: 4
# seen: 1
# seidl: 2
# selected: 4
# selection: 1
# selector: 1
# self: 8
# selflink: 9
# selfref: 3
# selling: 1
# seltzer: 2
# semantic: 2
# semantic_analysis_: 1
# semantics: 2
# semantics_: 1
# semanticscholar: 4
# semi: 4
# semma: 5
# sense: 2
# sentences: 1
# september: 3
# sequence: 2
# sequence_mining: 1
# sequential: 2
# sequential_pattern_mining: 1
# serbian: 1
# serbo: 1
# sergios: 1
# series: 3
# servers: 2
# service: 6
# services: 6
# set: 21
# sets: 9
# settings: 1
# settlement: 2
# several: 3
# sh: 4
# sh97002073: 1
# sha1: 1
# shadow: 9
# shapiro: 23
# shapiroparker2011: 1
# shapirosmyth1996: 1
# sharealike: 1
# sharealike_4: 2
# shield: 2
# shift: 2
# sholom: 1
# short: 8
# short_description: 2
# short_description_is_different_from_wikidata: 1
# shortdescription: 1
# shortened: 1
# should: 1
# show: 6
# showing: 1
# shqip: 1
# siampaper: 2
# side: 15
# sidebar: 96
# sidebar_with_collapsible_lists: 2
# sig: 2
# sigkdd: 10
# sigmod: 3
# significant: 1
# similar: 2
# similarly: 1
# simple: 7
# simplesearch: 1
# simplified: 1
# simulation: 1
# since: 5
# single: 2
# single_version_of_the_truth: 1
# sister_project: 2
# sistersitebox: 1
# site: 9
# sitedir: 1
# sitelinks: 1
# sitenotice: 2
# sitesub: 1
# sitesupport: 1
# situation: 12
# situation_in_europe: 4
# situation_in_europe_2: 4
# situation_in_the_united_states: 4
# situation_in_the_united_states_2: 4
# six: 2
# sixth: 2
# sixth_normal_form: 1
# size: 32
# sizing: 2
# sk: 4
# skin: 7
# skins: 5
# sl: 4
# slovak: 1
# slovenian: 1
# slovenčina: 1
# slovenščina: 1
# slowly: 2
# slowly_changing_dimension: 1
# small: 7
# smyth: 2
# sne: 1
# snooping: 3
# snowden: 2
# snowflake: 2
# snowflake_schema: 1
# so: 4
# social: 8
# social_computing: 1
# social_media_mining: 1
# social_software: 1
# society: 3
# socio: 1
# socs: 1
# software: 74
# software_configuration_management: 1
# software_construction: 1
# software_deployment: 1
# software_design: 1
# software_development: 1
# software_development_process: 1
# software_engineering: 1
# software_framework: 1
# software_maintenance: 1
# software_quality: 1
# software_repository: 1
# sol3: 1
# solid: 24
# solid_modeling: 1
# solution: 1
# som: 1
# some: 3
# sometimes: 2
# somewhat: 1
# sons: 2
# source: 13
# source_data_mining_software_and_applications: 4
# source_software: 1
# sources: 1
# south: 1
# space: 3
# spacing: 13
# spam: 2
# span: 849
# spanish: 1
# sparse: 1
# sparse_dictionary_learning: 1
# spatial: 2
# spatial_index: 1
# special: 59
# specially: 1
# specialpages: 2
# specific: 4
# specific_language: 1
# specifically: 6
# spectator: 2
# speech: 2
# spelling: 1
# spiders: 1
# spiking: 2
# spiking_neural_network: 1
# split: 2
# spreadsheet: 1
# spreadsheets: 2
# springer: 3
# springer_verlag: 1
# spss: 5
# spss_modeler: 1
# spurious_correlations_: 7
# spying: 2
# sq: 4
# sr: 4
# src: 17
# srcset: 11
# srpski: 1
# srpskohrvatski: 1
# ssrn: 4
# ssrn_: 1
# stable: 1
# stadler: 1
# stages: 1
# stakeholder: 4
# stalled: 1
# standard: 11
# standards: 10
# stanford: 3
# star: 4
# star_schema: 1
# start: 3
# startup: 2
# stat: 3
# state: 5
# statement: 1
# states: 11
# static: 12
# statistica: 3
# statistical: 21
# statistical_classification: 4
# statistical_hypothesis_testing: 1
# statistical_inference: 1
# statistical_learning_theory: 1
# statistical_model: 1
# statistical_noise: 1
# statistician: 1
# statisticians: 1
# statistics: 25
# stats: 1
# statslink: 1
# statsoft: 3
# status: 3
# steinbach: 1
# stellar: 2
# stellar_wind_: 1
# step: 6
# stephan: 2
# steps: 2
# steward: 1
# stewardship: 1
# sticky: 4
# stlr: 3
# stochastic: 1
# stopmobileredirecttoggle: 1
# storage: 5
# store: 2
# stored: 1
# stream: 1
# strengthen: 1
# strong: 1
# structure: 5
# structured: 9
# structured_data_analysis_: 1
# structured_prediction: 2
# structures: 3
# studies: 2
# style: 267
# styles: 19
# stylesheet: 2
# su: 4
# subdomain: 2
# subfield: 1
# subgroup: 13
# subject: 2
# sublist: 26
# subscription: 4
# subsection: 4
# subspace: 6
# subspace_clustering: 1
# subtitle: 1
# successors: 1
# such: 16
# sufficient: 1
# suggestededitsession: 1
# suggests: 1
# suite: 4
# summarization: 2
# summary: 3
# sunda: 1
# sundanese: 1
# suomi: 1
# sup: 114
# supermarket: 2
# supervised: 10
# supervised_learning: 5
# supplant: 1
# support: 18
# support_vector_machine: 1
# support_vector_machines: 2
# supported: 1
# surrogate: 2
# surrogate_key: 1
# surrounding: 1
# surveillance: 10
# surveillance_capitalism: 1
# survey: 3
# sv: 4
# svenska: 1
# svg: 56
# svm: 1
# swedish: 1
# swiss: 1
# switcher: 1
# switzerland: 1
# symbol_category_class: 6
# symbolic: 1
# synchronization: 2
# system: 32
# system_deployment: 1
# system_on_a_chip: 1
# systems: 8
# t: 21
# ta: 4
# tab: 5
# tabindex: 1
# table: 33
# tabs: 2
# tag: 1
# tagline: 3
# tags: 1
# taipale: 2
# taiwan: 1
# tajik: 1
# talk: 12
# tamil: 1
# tan: 1
# tanagra: 2
# tanagra_: 1
# target: 66
# targeted: 2
# targetloader: 1
# task: 6
# task_learning: 1
# tasks: 1
# taylor: 1
# tb: 2
# tbody: 22
# td: 119
# teaching: 1
# team: 2
# teams: 1
# technique: 1
# techniques: 11
# technology: 5
# teisseire: 1
# telecommunication: 2
# telecommunications: 2
# telephone: 1
# telpol: 3
# template: 53
# template_talk: 4
# templateargumentsize: 1
# templatestyles: 78
# temporal: 2
# temporal_difference_learning: 1
# tend: 1
# term: 10
# term_memory: 1
# terms: 8
# terms_of_use: 1
# test: 7
# test_set: 1
# testing: 2
# text: 219
# text_mining: 1
# text_of_the_creative_commons_attribution: 2
# tg: 4
# th: 76
# thai: 1
# than: 2
# that: 24
# the: 306
# their: 4
# them: 2
# theme: 1
# then: 5
# theodoridis: 1
# theorem: 2
# theoretical: 2
# theoretical_computer_science: 1
# theory: 18
# theory_of_computation: 1
# there: 5
# therefore: 1
# these: 7
# they: 5
# think: 1
# this: 55
# thomas: 2
# those: 1
# threat: 1
# through: 3
# throughout: 1
# thumb: 31
# thumbnail: 2
# thus: 2
# tibs: 3
# tibshirani: 5
# tiedonlouhinta: 2
# time: 14
# time_computing: 1
# time_data: 1
# time_series: 1
# times: 3
# timestamp: 2
# timeusage: 1
# timingprofile: 1
# title: 1037
# titlebar: 8
# titled: 1
# titleform: 1
# tiếng: 1
# to: 135
# toc: 234
# together: 2
# toggle: 20
# toggle_view_mobile: 1
# tokens: 1
# too: 3
# tool: 6
# tool_vendors: 1
# toolbar: 4
# toolkit: 2
# tools: 36
# tooltip: 5
# top: 35
# top_venues: 2
# topic: 3
# topics: 2
# torch: 2
# torch_: 1
# total: 4
# total_information_awareness: 1
# touch: 2
# tr: 136
# trademark: 1
# trademarked: 1
# tradeoff: 2
# train: 1
# trained: 4
# training: 3
# training_set: 1
# transactions: 1
# transclusion: 1
# transform: 8
# transformation: 5
# transformative: 2
# transformer: 3
# transformer_: 1
# transforming: 1
# transientcontent: 1
# transparent: 14
# tree: 3
# trees: 3
# trevor: 5
# trevor_hastie: 2
# triggered: 1
# true: 24
# truth: 2
# trying: 1
# ttl: 1
# turkish: 1
# turn: 2
# turned: 1
# tyler: 1
# type: 28
# typeahead: 4
# typeof: 9
# typography: 2
# të: 1
# türkçe: 1
# u: 14
# ubiquitous: 2
# ubiquitous_computing: 1
# ubiquity: 1
# ui: 28
# uid: 6
# uima: 4
# uk: 14
# ukrainian: 1
# ul: 250
# uli: 1
# uls: 5
# uncg: 5
# uncover: 2
# uncovering: 1
# uncovers: 1
# under: 12
# underscores: 1
# understanding: 2
# underway: 1
# unfairly: 1
# unfortunately: 1
# unintentionally: 1
# union: 3
# unit: 3
# united: 14
# universal_code_of_conduct: 1
# universities: 1
# university: 5
# unknown: 15
# unpin: 6
# unpinned: 12
# unstrip: 4
# unstructured: 2
# unsupervised: 4
# unsupervised_learning: 2
# unsupported_attributions: 1
# unusual: 2
# updated: 1
# updating: 1
# upholds: 1
# upload: 41
# upper: 4
# url: 8
# urlshortener: 3
# us: 5
# us_congress: 1
# usage: 5
# usama: 3
# usama_fayyad: 1
# use: 18
# used: 15
# uselang: 1
# user: 30
# user_behavior_analytics: 1
# useradd: 2
# userlogin: 2
# users: 1
# uses: 7
# using: 9
# using_a_data_warehouse: 1
# usually: 2
# utc: 1
# utf: 1
# utm_campaign: 1
# utm_medium: 1
# utm_source: 1
# ux: 1
# v: 4
# vague: 1
# valid: 1
# validation: 8
# validation_: 1
# validity: 1
# valign: 1
# value: 11
# vapnik: 2
# var: 2
# variable: 2
# variables: 1
# variance: 2
# variant: 3
# variants: 8
# variations: 1
# variety: 1
# various: 1
# vary: 1
# vault: 2
# vc: 1
# ve: 1
# vector: 437
# vendors: 1
# venomous: 1
# venues: 1
# verhees: 1
# veri: 1
# veri_madencili: 1
# verify: 1
# verlag: 1
# version: 5
# vertica: 3
# very: 4
# very_large_scale_integration: 1
# vi: 4
# via: 1
# victory: 2
# video: 3
# video_game: 1
# vietnamese: 1
# view: 17
# view_op: 2
# viewed: 1
# viewport: 1
# views: 3
# vigen: 1
# violates: 1
# violation: 2
# vipin: 1
# virtual: 4
# virtual_machine: 1
# virtual_reality: 1
# visible: 1
# vision: 6
# vision_transformer: 1
# visit: 2
# visited: 1
# visualeditor: 4
# visualisation: 1
# visualization: 5
# visualization_: 1
# việt: 1
# volume: 10
# voting: 2
# vq: 2
# vue: 2
# w: 59
# walgreens: 1
# walltime: 1
# warehouse: 16
# warehouses: 3
# warehousing: 5
# was: 15
# washington: 4
# washingtonspectator: 3
# watch: 1
# watchlist: 1
# watchtoken: 1
# way: 6
# wayback: 29
# wayback_machine: 13
# ways: 2
# wb: 4
# wbc: 1
# weasel: 7
# web: 85
# web_mining: 2
# web_scraping: 1
# webarchive: 3
# webarchive_template_wayback_links: 1
# website: 1
# week: 3
# weight: 22
# weiss: 3
# weka: 6
# weka_: 2
# welfare: 2
# well: 1
# welsh: 1
# were: 3
# wgaction: 1
# wgarticleid: 1
# wgbackendresponsetime: 1
# wgbreakframes: 1
# wgcanonicalnamespace: 1
# wgcanonicalspecialpagename: 1
# wgcategories: 1
# wgcentralauthmobiledomain: 1
# wgcheckuserclienthintsheadersjsapi: 1
# wgcurrevisionid: 1
# wgdefaultdateformat: 1
# wgdigittransformtable: 1
# wgeditsubmitbuttonlabelpublish: 1
# wgflaggedrevsparams: 1
# wggelevelingupenabledforuser: 1
# wggestructuredtaskrejectionreasontextinputenabled: 1
# wggetopicsmatchmodeenabled: 1
# wghostname: 1
# wgisarticle: 1
# wgisprobablyeditable: 1
# wgisredirect: 1
# wgmediaviewerenabledbydefault: 1
# wgmediavieweronclick: 1
# wgmfdisplaywikibasedescriptions: 1
# wgmonthnames: 1
# wgnamespacenumber: 1
# wgnoticeproject: 1
# wgpagecontentlanguage: 1
# wgpagecontentmodel: 1
# wgpagename: 1
# wgpageparsereport: 1
# wgpageviewlanguage: 1
# wgpopupsflags: 1
# wgrelevantarticleid: 1
# wgrelevantpageisprobablyeditable: 1
# wgrelevantpagename: 1
# wgrequestid: 1
# wgrestrictionedit: 1
# wgrestrictionmove: 1
# wgrevisionid: 1
# wgseparatortransformtable: 1
# wgtitle: 1
# wgulscurrentautonym: 1
# wgulsiscompactlinksenabled: 1
# wgulsislanguageselectorempty: 1
# wgulsposition: 1
# wgusergroups: 1
# wgusername: 1
# wgvisualeditor: 1
# wgwikibaseitemid: 1
# wgwmepagelength: 1
# wgwmeschemaeditattemptstepoversample: 1
# what: 2
# whatlinkshere: 2
# when: 6
# where: 1
# wherever: 1
# which: 15
# while: 2
# white: 3
# who: 4
# whom: 1
# wide: 3
# wider: 1
# width: 126
# wiki: 872
# wikibase: 6
# wikidata: 15
# wikimedia: 73
# wikimediabadges: 2
# wikimediaevents: 1
# wikimediafoundation: 2
# wikipedia: 190
# wikiproject: 3
# wikiproject_computer_science: 1
# wikisource: 1
# wikitext: 1
# wikt: 1
# wiktionary: 1
# wiley: 2
# will: 3
# william: 2
# wind: 2
# window: 2
# winning: 1
# with: 82
# withdrawn: 1
# within: 1
# without: 4
# witten: 11
# witten_8: 2
# wm: 1
# wmf: 2
# wojciech: 2
# word: 7
# word_processor: 1
# worded: 6
# worded_phrases: 1
# worded_phrases_from_august_2019: 1
# wordmark: 2
# words: 2
# words_to_watch: 1
# work: 1
# works: 2
# workshop: 3
# workstation: 1
# world: 3
# world_wide_web: 1
# worldcat: 3
# would: 2
# wpformidentifier: 1
# wrangling: 2
# wrap: 1
# wrapper: 1
# written: 4
# ws: 1
# wu: 1
# wuu: 4
# ww2: 2
# www: 56
# x: 11
# x1: 2
# xml: 8
# xml_for_analysis: 1
# xmla: 1
# y: 2
# ye: 1
# yes: 1
# yi: 4
# yiddish: 1
# yike: 1
# york: 3
# you: 6
# yu: 2
# yue: 4
# z: 2
# z39: 32
# z3988: 32
# zanasi: 1
# zebra: 2
# zh: 6
# zhouzh: 4
# čeština: 1
# δεδομένων: 1
# ελληνικά: 1
# εξόρυξη: 1
# български: 1
# даних: 1
# данни: 1
# добування: 1
# додаковӣ: 1
# знания: 1
# извличане: 1
# македонски: 1
# монгол: 1
# на: 1
# от: 1
# податочно: 1
# рударење: 1
# русский: 1
# српски: 1
# српскохрватски: 1
# тоҷикӣ: 1
# українська: 1
# հայերեն: 1
# մայնինգ: 1
# տվյալների: 1
# גראבן: 1
# דאטן: 1
# דיש: 1
# יי: 1
# כריית: 1
# מידע: 1
# עברית: 1
# البيانات: 1
# العربية: 1
# تنقيب: 1
# داده: 1
# دراوەکان: 1
# فارسی: 1
# في: 1
# پێکھاتەی: 1
# کاوی: 1
# کوردی: 1
# आ: 1
# उत: 1
# कड: 1
# खनन: 2
# ठ: 1
# द: 2
# न: 1
# मर: 1
# व: 1
# ह: 1
# অসম: 1
# ইন: 1
# উপ: 1
# খনন: 1
# ট: 1
# ড: 1
# ত: 2
# ব: 1
# ম: 1
# য: 1
# ল: 1
# அகழ: 1
# தம: 1
# தரவ: 1
# தல: 1
# ழ: 1
# ಕ: 1
# ಕನ: 1
# ಗ: 1
# ಗಣ: 1
# ತ: 1
# ದತ: 1
# ನಡ: 1
# ರ: 1
# ಶ: 1
# ങ: 2
# ഡ: 1
# ന: 1
# മ: 1
# മലയ: 1
# റ: 2
# ള: 1
# การทำเหม: 1
# ล: 1
# องข: 1
# อม: 1
# ไทย: 1
# ခ: 1
# င: 1
# တ: 2
# ဒ: 1
# န: 1
# ဖ: 1
# ဘ: 1
# မ: 2
# သ: 1
# データマイニング: 1
# 中文: 1
# 吴语: 1
# 数据挖掘: 2
# 數據探勘: 1
# 日本語: 1
# 粵語: 1
# 데이터: 1
# 마이닝: 1
# 한국어: 1
#
# Unique Terms and Their Counts for doc6.txt:
# 0: 16
# 00: 1
# 000: 2
# 0005ff: 1
# 0064ac: 11
# 017023: 1
# 031fc4: 6
# 0px: 3
# 0test: 1
# 1: 5
# 10: 2
# 100: 18
# 11: 2
# 1109: 1
# 12: 17
# 140px: 12
# 140x140: 17
# 150: 2
# 1550320: 1
# 15px: 14
# 16th: 2
# 17: 1
# 17th: 1
# 18th: 2
# 1d2a92: 1
# 2: 5
# 20: 3
# 200: 2
# 2003: 1
# 2004: 1
# 200486_washkewicz_magazine_2020_2021: 1
# 2005: 2
# 2006: 2
# 2007: 1
# 2008: 1
# 2009: 4
# 200px: 4
# 2010: 2
# 2011: 1
# 2012: 1
# 2013: 1
# 2015: 3
# 2016: 8
# 2017: 12
# 2018: 16
# 2019: 21
# 2020: 10
# 2021: 6
# 2022: 10
# 2023: 25
# 2024: 10
# 20px: 11
# 21: 2
# 22: 2
# 2211: 2
# 2327: 2
# 23rd: 1
# 24px: 1
# 28px: 6
# 2nd: 1
# 3: 7
# 300px: 2
# 30px: 1
# 3274474: 1
# 340px: 11
# 38px: 1
# 4: 23
# 40: 1
# 408: 1
# 40px: 3
# 430: 1
# 433: 1
# 44: 1
# 460: 1
# 465: 1
# 469: 1
# 47: 2
# 492: 3
# 4th: 1
# 5: 4
# 53: 3
# 530: 1
# 5611: 1
# 570: 1
# 593: 3
# 5d2a92: 1
# 6: 36
# 601: 1
# 611: 1
# 612: 1
# 648: 1
# 660: 1
# 695: 1
# 7: 1
# 7203: 1
# 7211: 1
# 734: 1
# 7938: 1
# 7946: 1
# 7th: 1
# 8: 4
# 8939: 1
# 8th: 1
# 9999: 1
# a: 173
# abay: 2
# abhinav: 1
# abhishek: 1
# about: 1
# absolute: 1
# abstract: 1
# academia: 3
# academic: 1
# accepted: 1
# access: 3
# accounting: 1
# acknowledgement: 1
# activated: 2
# active: 4
# additional: 1
# address: 2
# advanced: 3
# advising: 1
# after: 1
# aggregate: 2
# ahiagbedey: 1
# ai: 6
# aibigdatalab: 1
# aidan: 1
# al: 7
# aldyaflah: 2
# align: 15
# all: 1
# almusawi: 2
# alt: 19
# amazon: 2
# amount: 2
# an: 2
# analysis: 29
# analytic: 8
# analytics: 23
# anastasiya: 2
# and: 104
# andrew: 8
# andrew_bcd2019: 1
# anomaly: 2
# answering: 14
# anti: 3
# apple: 2
# application: 5
# applications: 3
# approach: 4
# approval: 1
# april: 3
# aqeel: 3
# arcy: 11
# are: 1
# areas: 4
# aria: 6
# aring: 6
# article: 2
# as: 8
# asanka: 3
# aspect: 12
# asset: 3
# at: 15
# attention: 2
# august: 4
# auto: 7
# automated: 2
# automatic: 9
# automation: 2
# award: 12
# awarded: 2
# awards: 2
# aware: 1
# aya: 3
# b: 106
# background: 18
# background2: 1
# bakushi: 3
# ball: 6
# bank: 3
# based: 27
# basketball: 7
# bd: 1
# be: 2
# before: 1
# beige: 1
# below: 1
# benchmark: 1
# benjamin: 2
# berkman: 1
# bert: 2
# best: 6
# bethu: 2
# better: 1
# between: 1
# bhatt: 2
# bidirectional: 2
# big: 49
# bigdata: 1
# bigdataworkshop2019csu: 1
# bills: 1
# binarization: 1
# biometrics: 2
# black: 15
# blockchain: 2
# blockquote: 33
# boca: 2
# body: 2
# book: 2
# bootstrap: 4
# bootstrap3: 1
# boston: 1
# bottom: 6
# br: 159
# brian: 1
# brought: 1
# btn: 18
# building: 2
# built: 1
# busch: 1
# button: 6
# by: 20
# c600fc: 1
# cadetblue: 2
# california: 1
# campus: 1
# candidate: 2
# capitani: 1
# cardiac: 2
# carmen: 1
# case: 6
# censorships: 2
# center: 40
# centric: 3
# cerbro: 1
# cerebro: 4
# cf9495: 1
# changes: 1
# changing: 1
# chapter: 1
# chapters: 1
# charset: 1
# chase: 1
# china: 1
# chun: 1
# chung: 45
# cipher: 2
# circle: 6
# cis: 15
# cis408: 2
# cis430: 1
# cis430fall24: 1
# cis433: 2
# cis465: 2
# cis593: 6
# cis601: 2
# cis611: 2
# cis612: 2
# cis612fall24: 1
# cis660: 1
# cis660fall24: 1
# cis711: 1
# cis712: 1
# cis760: 1
# class: 147
# classification: 1
# cleary: 1
# cleveland: 8
# clinic: 1
# cloud: 10
# cns: 1
# coding: 2
# col: 64
# collaboration: 9
# collaborative: 7
# collapse: 3
# college: 13
# color: 52
# colorado: 1
# cols: 1
# columnar: 1
# com: 1
# commerce: 2
# committee: 3
# compatible: 1
# compiled: 1
# completed: 12
# compromising: 2
# computational: 3
# computer: 4
# computing: 7
# concept: 4
# conference: 11
# congress: 1
# connor: 1
# construction: 1
# contact: 2
# contain: 11
# container: 7
# content: 4
# context: 3
# contextual: 1
# control: 3
# controls: 1
# corp: 6
# correlated: 1
# countless: 1
# course: 1
# courses: 1
# cross: 1
# cs: 6
# css: 3
# csu: 21
# csuohio: 18
# current: 6
# currently: 1
# customized: 1
# cwru: 3
# cyber: 7
# cybersecurity: 1
# d: 23
# danielle: 6
# danny: 1
# dasepalli: 1
# data: 107
# database: 9
# databases: 9
# david: 3
# day: 3
# dbms: 1
# dbs: 1
# de: 2
# deaf: 1
# deajeon: 1
# dean: 1
# dec: 10
# december: 2
# deep: 11
# default: 3
# defect: 3
# defection: 3
# defense: 14
# delta: 2
# demo: 2
# democratized: 1
# dennis: 6
# dept: 1
# describedby: 3
# desert: 6
# design: 12
# details: 6
# detection: 12
# developed: 1
# development: 4
# device: 1
# di: 1
# diagnostics: 1
# diego: 8
# dipakkumar: 2
# directions: 1
# disciplinary: 1
# disclosure: 1
# disease: 1
# disparity: 3
# display: 3
# dissertation: 14
# distributed: 3
# div: 132
# dixon: 1
# doctoral: 4
# doctype: 1
# document: 11
# doi: 1
# domain: 2
# dorothy: 2
# douglas: 1
# dr: 8
# dsa: 2
# dsa460: 2
# dsa460sp24: 2
# durga: 1
# during: 3
# durkin: 1
# e: 5
# e4aaf7: 1
# earl: 1
# earnst: 1
# ecosystem: 4
# edge: 2
# eds: 1
# edu: 17
# eecs: 16
# eeg: 2
# efa590: 1
# el: 10
# election: 3
# electroencephalography: 2
# element: 2
# email: 7
# emailhelp: 2
# embeddings: 1
# emerging: 2
# en: 1
# encoder: 2
# encrypted: 6
# encryption: 3
# energy: 2
# engine: 3
# engineering: 17
# enter: 3
# enterprise: 3
# environment: 1
# equality: 1
# equiv: 1
# establishment: 1
# estate: 7
# et: 7
# etten: 1
# every: 1
# evidence: 3
# example: 1
# excit: 2
# executive: 1
# expand: 1
# expanded: 1
# experimental: 2
# extended: 1
# extension: 1
# extraction: 2
# f7be86: 1
# f97400: 2
# fabio: 1
# facebook: 1
# faculty: 6
# facultybio_sunniechung: 2
# fall: 6
# false: 1
# fame: 1
# fault: 1
# feature: 3
# featuring: 1
# federated: 2
# feedbackform: 1
# feedbacksubmit: 1
# ferencz: 2
# fh305: 1
# fi: 2
# file: 3
# files: 2
# find: 1
# fingerprinting: 2
# firm: 1
# first: 6
# fit: 11
# fixed: 2
# fl: 1
# florida: 2
# foaf: 2
# focus: 1
# font: 26
# food: 6
# footer: 2
# for: 57
# form: 13
# formal: 1
# foundation: 4
# framework: 1
# frd: 1
# from: 5
# fully: 3
# funded: 7
# funding: 1
# gabriel: 1
# game: 1
# garcia: 1
# geospatial: 5
# geri: 4
# gif: 8
# github: 1
# glove: 1
# golden: 2
# graduate: 7
# graduated: 2
# graduates: 1
# graduation: 1
# grant: 8
# grants: 2
# graph: 12
# gray: 1
# group: 3
# gultekin: 5
# h2: 8
# h3: 16
# hadoop: 1
# hall: 1
# hannifin: 1
# hawaii: 1
# hayden: 2
# he: 1
# head: 2
# header: 4
# health: 11
# height: 22
# heterogeneous: 1
# highest: 1
# hinojosa: 1
# holder: 17
# home: 2
# homomorphic: 3
# honeydew: 2
# hongkong: 1
# honolulu: 1
# honor: 4
# hosted: 1
# how: 2
# href: 51
# html: 23
# http: 1
# https: 17
# huang: 1
# hubs: 1
# husan: 2
# hyland: 1
# i: 23
# ian: 1
# ibm: 8
# icde: 1
# icmla: 1
# icon: 1
# id: 11
# identification: 13
# idr: 1
# ie: 1
# ieee: 15
# ifip: 1
# ii: 1
# ijndc: 1
# image: 5
# images: 18
# img: 32
# in: 84
# include: 2
# indentification: 1
# independent: 3
# index: 3
# index_old_teaching: 6
# individual: 1
# industry: 5
# infectious: 1
# information: 4
# infrastructure: 2
# infrastructures: 1
# initial: 3
# input: 2
# integrated: 9
# intelligence: 3
# intelligent: 6
# intellignet: 2
# intension: 1
# intent: 1
# international: 12
# internet: 2
# intrusion: 9
# invention: 1
# invited: 6
# iot: 12
# iotc: 1
# is: 1
# issn: 5
# issue: 2
# ist: 1
# ist734: 2
# item: 4
# izdehar: 2
# jafar: 2
# jan: 6
# javascript: 1
# jesus: 1
# jimenez: 1
# jimmy: 2
# jingyuan: 2
# jinjie: 3
# jjliu_poster_fulldescription0914: 2
# joe: 2
# joel: 2
# join: 2
# joint: 1
# jonmbake: 1
# journal: 10
# jp: 1
# jpg: 18
# jquery: 2
# js: 6
# julien: 1
# july: 3
# jumbotron: 3
# katalina: 2
# kelly: 1
# key: 1
# kluwer: 1
# knowledge: 13
# korea: 1
# lab: 13
# label: 7
# labhesh: 2
# land: 2
# landed: 1
# lang: 1
# language: 18
# large: 4
# last: 6
# lead: 1
# learing: 1
# learn: 1
# learning: 42
# left: 5
# left1: 3
# legislative: 1
# leicester: 2
# leonid: 1
# level: 1
# lg: 27
# li: 292
# liang: 2
# life: 1
# linear: 2
# link: 11
# list: 3
# liu: 3
# local: 1
# logging: 2
# luo: 3
# machine: 30
# magazine: 1
# mail: 2
# major: 1
# management: 7
# mananayaka: 3
# many: 1
# map: 1
# march: 2
# margin: 5
# mark_null_equal: 1
# marser: 2
# master: 21
# max: 11
# may: 21
# mb: 14
# mccoy: 2
# mckinsey: 2
# md: 8
# mechanism: 2
# media: 8
# medical: 12
# medicalqa_asanka: 1
# meil: 1
# members: 5
# merit: 3
# message: 6
# messagehelp: 2
# meta: 3
# metabolomic: 2
# method: 2
# methods: 4
# metro: 1
# miami: 1
# michael: 1
# midwest: 1
# mike: 10
# million: 1
# min: 2
# ming: 1
# mining: 5
# ml: 1
# model: 3
# modeling: 2
# models: 3
# modern: 1
# monitoring: 1
# more: 2
# morgan: 1
# mpp: 4
# mr: 6
# mrunal: 2
# ms: 2
# mscs: 8
# msse: 8
# mt: 2
# multi: 1
# multimedia: 1
# murillo: 1
# mute: 1
# muted: 3
# mutual: 1
# mx: 2
# mydiv: 1
# name: 15
# namehelp: 2
# nathan: 1
# nathanael: 1
# natural: 11
# nature: 1
# nav: 11
# navbar: 6
# navbarsupportedcontent: 3
# navigation: 1
# nba: 7
# nbsp: 3
# ncr: 2
# necessary: 1
# needed: 1
# negomedzyanov: 1
# net: 4
# network: 14
# networked: 1
# networks: 4
# neural: 4
# nicholas: 1
# nick: 5
# nlp: 3
# nlp1: 1
# no: 2
# none: 3
# north: 1
# nov: 3
# now: 2
# nsf: 2
# null: 1
# object: 11
# oct: 7
# of: 82
# offensive: 1
# office: 1
# oh: 1
# olap: 1
# on: 59
# online: 2
# only: 9
# opinion: 6
# optimization: 8
# optimizer: 1
# or: 1
# oracle: 1
# other: 1
# our: 1
# out: 1
# over: 2
# ozsoyoglu: 5
# p: 297
# padding: 13
# page: 1
# pan: 4
# paper: 7
# paradigm: 2
# parallel: 6
# park: 1
# parker: 1
# part: 2
# partitioning: 1
# patel: 7
# patent: 1
# patient: 3
# patients: 2
# pdf: 25
# pdw: 4
# peer: 4
# people: 5
# performance: 1
# ph: 9
# phd: 6
# phillips: 1
# pilot: 1
# placeholder: 3
# platform: 1
# play: 1
# plays: 6
# please: 3
# plugins: 2
# pnc: 1
# png: 2
# popoli: 2
# popoola: 2
# popper: 1
# position: 3
# post: 1
# poster: 11
# poster_antitampercloud_03: 1
# posters: 1
# posters_: 2
# pourbemany: 2
# powderblue: 1
# practical: 3
# prague: 1
# predicate: 1
# prediction: 4
# predictor: 1
# present: 6
# presentation: 3
# presentations: 1
# preserving: 4
# president: 1
# presidential: 3
# presidentialelectionprediction_socialmediaopinionanalysis: 3
# prestigious: 2
# primary: 2
# print: 3
# privacy: 12
# prize: 4
# proceeding: 1
# proceedings: 7
# process: 3
# processing: 28
# professional: 1
# progressive: 2
# project: 18
# projects: 4
# prompting: 2
# property: 7
# proposal: 25
# proposals: 2
# protect: 1
# public: 5
# publication: 3
# publications: 5
# published: 1
# publisher: 1
# qing: 2
# qipnet: 2
# quarcoo: 2
# queries: 2
# query: 6
# querying: 5
# question: 14
# quick: 2
# r: 1
# random: 2
# raton: 2
# real: 16
# realtime: 1
# recent: 1
# recognition: 3
# recommendation: 12
# recommendationsystem_1: 1
# recommendationsystem_2: 1
# record: 1
# reduce: 1
# reid: 1
# rel: 1
# rendered: 17
# repeat: 2
# reports: 1
# representations: 2
# research: 40
# researchposter_eecs_sunniechung_daniellearing: 2
# researchposter_eecs_sunniechung_mikedarcy_utkarshpatel: 2
# researchposters_nlpteam: 1
# researchthesis_mlbasedidentification_urbanfooddesertdefect_dorothyzhao: 1
# reserve: 5
# resident: 1
# retrieval: 2
# reviewed: 4
# rewrite: 3
# reynolds: 2
# riehl: 2
# right: 7
# right1: 3
# risch: 6
# risk: 1
# rock: 1
# rockwell: 1
# role: 1
# roll: 1
# romano: 1
# rounded: 6
# row: 11
# rows: 1
# ryan: 2
# s: 12
# sabrina: 1
# salvador: 1
# sam: 2
# san: 8
# scale: 14
# schizophrenia: 2
# science: 7
# scientific: 1
# scientist: 1
# screen: 1
# screens: 5
# script: 6
# sdfirstprizewinner: 1
# sdfirstprizewinner_1: 1
# sean: 2
# search: 11
# secondary: 1
# section: 9
# secure: 2
# security: 12
# see: 1
# seed: 1
# seedcorn: 1
# segundo: 8
# selected: 1
# selection: 3
# selective: 2
# semantic: 9
# semi: 4
# seminar: 1
# send: 2
# senior: 21
# sensing: 2
# sensitive: 1
# sentiment: 7
# sept: 2
# september: 1
# sequenced: 3
# service: 5
# shape: 1
# sharesci: 4
# she: 1
# sherwin: 1
# sign: 1
# signals: 4
# simplification: 1
# singer: 3
# sites: 1
# six: 1
# size: 28
# sm: 24
# so: 1
# social: 8
# socialmedia: 2
# society: 2
# software: 1
# south: 1
# southern: 1
# span: 16
# spatial: 2
# special: 1
# specific: 2
# sport: 1
# sport2: 1
# spring: 10
# springer: 1
# sql: 1
# sr: 4
# sravya: 2
# src: 24
# sridhar: 1
# srinivas: 1
# sschung: 15
# start: 1
# state: 2
# stell: 2
# stream: 1
# strong: 16
# student: 1
# students: 13
# studies: 1
# study: 3
# stuents: 1
# style: 100
# stylesheet: 1
# submission: 3
# submit: 1
# submitted: 5
# subquery: 1
# subsystem: 2
# success: 1
# suhua: 1
# suleimenov: 2
# summer: 13
# sun: 27
# sunnie: 35
# sunniechungpic: 2
# supervised: 4
# supervision: 6
# supervisions: 2
# supervisor: 2
# support: 3
# survey: 1
# symposium: 3
# system: 40
# systems: 15
# tables: 1
# tail: 2
# talk: 3
# talks: 2
# tamper: 3
# tan: 1
# target: 1
# targeted: 1
# teaching: 9
# team: 8
# team_intelli: 2
# teams: 1
# tech: 2
# technology: 1
# tejomurthula: 1
# temporal: 5
# teradata: 9
# test2: 1
# test3: 1
# testbed: 2
# tetci: 2
# text: 43
# textanalysisnlpresearchteam: 1
# textanalysisnlpresearchteam2: 1
# textarea: 2
# the: 45
# their: 1
# thesis: 37
# things: 1
# this: 1
# thumbnail: 11
# time: 13
# timeout: 2
# title: 23
# titled: 2
# to: 20
# toggle: 2
# toggler: 2
# top: 10
# topic: 3
# topics: 4
# training: 2
# transaction: 1
# transactions: 2
# transformers: 2
# translating: 1
# troy: 1
# true: 17
# trusted: 2
# type: 5
# typeof: 2
# u: 1
# ua: 1
# uk: 2
# ul: 6
# under: 4
# undergraduate: 3
# univeristy: 1
# univerity: 1
# university: 11
# unsupervised: 2
# untargeted: 1
# urban: 8
# urbanrealestateseniordesign_poster: 2
# urbanrealestateteam: 1
# url: 2
# usc: 1
# use: 2
# using: 7
# utf: 1
# utkarsh: 7
# v3nickwhite: 2
# valid: 1
# van: 1
# view: 6
# viewport: 1
# villalobos: 1
# vimercati: 1
# visual: 2
# vldb: 1
# voice: 2
# vol: 3
# volumn: 1
# warehouse: 11
# was: 1
# washkewicz_college_magazine_sunniechung_published_200486: 1
# wceam: 2
# wearables: 2
# web: 1
# website: 2
# wei: 1
# weighted: 1
# wenbing: 1
# western: 6
# where: 2
# white: 10
# wi: 2
# width: 27
# wiki_poster: 2
# williams: 1
# winner: 7
# winning: 3
# wise: 1
# with: 50
# women: 1
# word: 1
# work: 1
# workshop: 11
# workshopbigdatalab: 1
# workshops: 1
# wu: 3
# x: 1
# xl: 2
# xviii: 1
# years: 7
# yixi: 3
# yiyuan: 2
# young: 1
# your: 1
# yu: 8
# z: 1
# zapotechne: 1
# zavier: 1
# zhao: 3

# %%
import pandas as pd
import re
import math
from collections import defaultdict

# Step 1: Import necessary libraries & Mount Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Step 2: Define File Paths
folder_path = "/content/drive/MyDrive/Colab Notebooks/datamining/Lab2/docs/"
file_names = [f"{folder_path}doc{i}.txt" for i in range(1, 7)]

# Extract document names from file paths
doc_names = [f"doc{i}" for i in range(1, 7)]

# Step 3: Read and Compute Term Frequencies for Each Document
term_freq = defaultdict(dict)
all_terms = set()

for file_name in file_names:
    with open(file_name, 'r') as f:
        text = f.read().lower()  # Convert to lowercase

    tokens = re.findall(r'\b\w+\b', text)
    all_terms.update(tokens)

    for token in tokens:
        if token not in term_freq[file_name]:
            term_freq[file_name][token] = 0
        term_freq[file_name][token] += 1

# Step 4: Calculate Document Frequency (DF) and Inverse Document Frequency (IDF) for Each Term
df = {term: 0 for term in all_terms}
for term in all_terms:
    df[term] = sum(1 for doc in term_freq if term in term_freq[doc])

idf = {}
total_docs = len(file_names)
for term, freq in df.items():
    if freq == 0:
        idf[term] = 0
    else:
        idf[term] = math.log(total_docs / freq)

# Step 5: Calculate TF-IDF for Each Term in Each Document
tf_idf = {}
for doc, frequencies in term_freq.items():
    tf_idf[doc] = {}
    for term, freq in frequencies.items():
        if term in idf:  # Ensure the term is in idf
            tf_idf[doc][term] = freq * idf[term]

# Step 6: Calculate Collection Frequency (CF) and Max TF
collection_freq = defaultdict(int)
max_tf = defaultdict(lambda: defaultdict(int))

for doc, frequencies in term_freq.items():
    for term, freq in frequencies.items():
        collection_freq[term] += freq
        if freq > max_tf[doc][term]:
            max_tf[doc][term] = freq

# Step 7: Create the Postings File
postings_file = defaultdict(list)

for doc, doc_name in zip(file_names, doc_names):
    with open(doc, 'r') as f:
        text = f.read().lower()
    tokens = re.findall(r'\b\w+\b', text)
    for position, token in enumerate(tokens):
        if token in all_terms:
            postings_file[token].append((doc_name, position))

# Step 8: Build the Inverted Index (Term Dictionary) with Additional Details
inverted_index = {}
for term in all_terms:
    inverted_index[term] = {}
    for doc, doc_name in zip(tf_idf, doc_names):
        if term in tf_idf[doc] and tf_idf[doc][term] > 0:
            inverted_index[term][doc_name] = {
                'TF-IDF': tf_idf[doc][term],
                'CF': collection_freq[term],
                'Max TF': max_tf[doc][term],
                'DF': df[term]
            }

# Step 9: Display the Postings File
postings_data = []
for term, postings in postings_file.items():
    for doc, position in postings:
        postings_data.append([term, doc, position])

df_postings = pd.DataFrame(postings_data, columns=["Term", "Document", "Position"])
display(df_postings)

# Step 10: Display the Dictionary File
dictionary_data = []
for term, docs in inverted_index.items():
    for doc, details in docs.items():
        dictionary_data.append([
            term, doc, details['TF-IDF'], details['CF'], details['Max TF'], details['DF']
        ])

df_dictionary = pd.DataFrame(dictionary_data, columns=["Term", "Document", "TF-IDF", "Collection Frequency", "Max TF", "Doc Freq"])
display(df_dictionary)
# Out:
# Mounted at /content/drive
#                   Term Document  Position
# 0              doctype     doc1         0
# 1              doctype     doc2         0
# 2              doctype     doc3         0
# 3              doctype     doc4         0
# 4              doctype     doc5         0
# ...                ...      ...       ...
# 289573     messagehelp     doc6      6776
# 289574     messagehelp     doc6      6780
# 289575  feedbacksubmit     doc6      6799
# 289576         plugins     doc6      6842
# 289577         plugins     doc6      6856
#
# [289578 rows x 3 columns]
#              Term Document     TF-IDF  Collection Frequency  Max TF  Doc Freq
# 0            4cc1     doc1   3.583519                     2       2         1
# 1          60bc61     doc1   1.791759                     1       1         1
# 2        sciences     doc1   0.364643                    30       2         5
# 3        sciences     doc2   2.187859                    30      12         5
# 4        sciences     doc3   1.093929                    30       6         5
# ...           ...      ...        ...                   ...     ...       ...
# 21180  7cwikibase     doc2   0.693147                     3       1         3
# 21181  7cwikibase     doc4   0.693147                     3       1         3
# 21182  7cwikibase     doc5   0.693147                     3       1         3
# 21183    snapshot     doc1  71.670379                    40      40         1
# 21184         2c5     doc1   3.583519                     2       2         1
#
# [21185 rows x 6 columns]

# %% [markdown]
# **### NOT the below codes ~!!**

# %%
# Calculate Collection Frequency (CF) and Max TF for each term in each document
collection_freq = defaultdict(int)
max_tf = defaultdict(lambda: defaultdict(int))

for doc, frequencies in term_freq.items():
    for term, freq in frequencies.items():
        collection_freq[term] += freq
        if freq > max_tf[doc][term]:
            max_tf[doc][term] = freq

# Add CF and Max TF to the inverted index
for term in terms:
    for doc in tf_idf:
        if tf_idf[doc][term] > 0:
            inverted_index[term][doc] = {
                'TF-IDF': tf_idf[doc][term],
                'CF': collection_freq[term],
                'Max TF': max_tf[doc][term]
            }

# %%
# Create the Postings File
postings_file = defaultdict(list)

for doc in file_names:
    with open(doc, 'r') as f:
        text = f.read().lower()
    tokens = re.findall(r'\b\w+\b', text)
    for position, token in enumerate(tokens):
        if token in terms:
            postings_file[token].append((doc, position))

# Display the Postings File
postings_data = []
for term, postings in postings_file.items():
    for doc, position in postings:
        postings_data.append([term, doc, position])

df_postings = pd.DataFrame(postings_data, columns=["Term", "Document", "Position"])
display(df_postings)
# Out:
#         Term                                           Document  Position
# 0       data  /content/drive/MyDrive/Colab Notebooks/datamin...        10
# 1       data  /content/drive/MyDrive/Colab Notebooks/datamin...       261
# 2       data  /content/drive/MyDrive/Colab Notebooks/datamin...       452
# 3       data  /content/drive/MyDrive/Colab Notebooks/datamin...      1107
# 4       data  /content/drive/MyDrive/Colab Notebooks/datamin...      1501
# ...      ...                                                ...       ...
# 2773  mining  /content/drive/MyDrive/Colab Notebooks/datamin...       667
# 2774  mining  /content/drive/MyDrive/Colab Notebooks/datamin...      3596
# 2775  mining  /content/drive/MyDrive/Colab Notebooks/datamin...      4211
# 2776  mining  /content/drive/MyDrive/Colab Notebooks/datamin...      4420
# 2777  mining  /content/drive/MyDrive/Colab Notebooks/datamin...      4470
#
# [2778 rows x 3 columns]

# %%
# Display the Dictionary File
dictionary_data = []
for term, docs in inverted_index.items():
    for doc, details in docs.items():
        dictionary_data.append([
            term, doc, details['TF-IDF'], details['CF'], details['Max TF'], df[term]
        ])

df_dictionary = pd.DataFrame(dictionary_data, columns=["Term", "Document", "TF-IDF", "Collection Frequency", "Max TF", "Doc Freq"])
display(df_dictionary)
# Out:
#         Term                                           Document      TF-IDF  \
# 0     mining  /content/drive/MyDrive/Colab Notebooks/datamin...    8.514767
# 1     mining  /content/drive/MyDrive/Colab Notebooks/datamin...  113.530230
# 2     mining  /content/drive/MyDrive/Colab Notebooks/datamin...  113.530230
# 3     mining  /content/drive/MyDrive/Colab Notebooks/datamin...    2.027326
# 4  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...    8.022148
# 5  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...    0.182322
# 6  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...    3.464110
# 7  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...    3.464110
# 8  analytics  /content/drive/MyDrive/Colab Notebooks/datamin...    4.193396
#
#    Collection Frequency  Max TF  Doc Freq
# 0                   586      21         4
# 1                   586     280         4
# 2                   586     280         4
# 3                   586       5         4
# 4                   106      44         5
# 5                   106       1         5
# 6                   106      19         5
# 7                   106      19         5
# 8                   106      23         5

# %% [markdown]
# ### **PART 2 BEGINS**

# %% [markdown]
# Part2:
# In this section, we'll construct a cosine similarity matrix using the term frequencies calculated earlier. We'll also normalize each document vector to calculate the cosine similarity.

# %% [markdown]
# Step 1: Display Document Vectors for Keywords
#
# This step is for visualization to get a grasp on our document vectors before we compute cosine similarities.

# %%
# Convert the term frequencies dictionary to a DataFrame for a clearer display
df_term_freq = pd.DataFrame({doc.split('/')[-1]: tf for doc, tf in term_freq.items()}).T

# Replace NaN values (indicating a term wasn't found in a document) with 0
df_term_freq.fillna(0, inplace=True)

# Ensure all values are integers, as term frequencies are whole numbers
df_term_freq = df_term_freq.astype(int)

# Display the DataFrame
print("Document Vectors For Keywords:")
df_term_freq
# Out:
# Document Vectors For Keywords:
#           research  data  mining  analytics  machine learning  deep learning  \
# doc1.txt        13   296       0         44                 0              0
# doc2.txt        31   264      21          0                 0              0
# doc3.txt       110    21       0          1                 0              0
# doc4.txt        27   575     280         19                 0              0
# doc5.txt        27   575     280         19                 0              0
# doc6.txt        40   107       5         23                 0              0
#
#           data mining
# doc1.txt            0
# doc2.txt            0
# doc3.txt            0
# doc4.txt            0
# doc5.txt            0
# doc6.txt            0

# %% [markdown]
# Step 2: Normalize Each Document Vector
#
# Before calculating cosine similarity, vectors should be normalized (i.e., have a magnitude of 1).

# %%
def normalize_vector(vector):
    magnitude = math.sqrt(sum([val**2 for val in vector.values()]))
    if magnitude == 0:
        return vector
    return {term: val/magnitude for term, val in vector.items()}

# Assuming term_freq is a dictionary of term frequencies for each document
normalized_vectors = {doc.split('/')[-1]: normalize_vector(tf) for doc, tf in term_freq.items()}

# Convert to DataFrame for tabular representation
df = pd.DataFrame(normalized_vectors).transpose()

# Display the DataFrame
print(df)
# Out:
#           research      data    mining  analytics  machine learning  \
# doc1.txt  0.043401  0.988200  0.000000   0.146895               0.0
# doc2.txt  0.116261  0.990091  0.078757   0.000000               0.0
# doc3.txt  0.982221  0.187515  0.000000   0.008929               0.0
# doc4.txt  0.042161  0.897873  0.437225   0.029669               0.0
# doc5.txt  0.042161  0.897873  0.437225   0.029669               0.0
# doc6.txt  0.342959  0.917416  0.042870   0.197202               0.0
#
#           deep learning  data mining
# doc1.txt            0.0          0.0
# doc2.txt            0.0          0.0
# doc3.txt            0.0          0.0
# doc4.txt            0.0          0.0
# doc5.txt            0.0          0.0
# doc6.txt            0.0          0.0

# %% [markdown]
# Step 3: Calculate Cosine Similarity Between Pairs of documents

# %%
import math
import pandas as pd
def cosine_similarity(vec1, vec2):
    dot_product = sum([vec1[term] * vec2.get(term, 0) for term in vec1.keys()])
    magnitude1 = math.sqrt(sum([val**2 for val in vec1.values()]))
    magnitude2 = math.sqrt(sum([val**2 for val in vec2.values()]))
    if magnitude1 * magnitude2 == 0:  # Avoid division by zero
        return 0
    return dot_product / (magnitude1 * magnitude2)
    cosine_sim_matrix = {doc1: {doc2: cosine_similarity(normalized_vectors[doc1], normalized_vectors[doc2])
                           for doc2 in file_names} for doc1 in file_names}
    cosine_sim_matrix
    # Assuming normalized_vectors is a dictionary of document vectors
# and file_names is a list of document names
    cosine_sim_matrix = {doc1: {doc2: cosine_similarity(normalized_vectors[doc1], normalized_vectors[doc2])
                           for doc2 in file_names} for doc1 in file_names}
    # Convert the dictionary to a pandas DataFrame for better display
    cosine_sim_df = pd.DataFrame(cosine_sim_matrix)
    # Display the DataFrame
    print(cosine_sim_df)
# Out:
#           doc1.txt  doc2.txt  doc3.txt  doc4.txt  doc5.txt  doc6.txt
# doc1.txt  1.000000  0.983454  0.229243  0.893466  0.893466  0.950443
# doc2.txt  0.983454  1.000000  0.299851  0.928313  0.928313  0.951575
# doc3.txt  0.229243  0.299851  1.000000  0.210041  0.210041  0.510652
# doc4.txt  0.893466  0.928313  0.210041  1.000000  1.000000  0.862778
# doc5.txt  0.893466  0.928313  0.210041  1.000000  1.000000  0.862778
# doc6.txt  0.950443  0.951575  0.510652  0.862778  0.862778  1.000000

# %% [markdown]
# Step 4: Display the Cosine Similarity Matrix in Tabular Form

# %%
# Convert the cosine similarity matrix to a DataFrame for better display
df_cosine_sim = pd.DataFrame(cosine_sim_matrix).T

# Display the matrix
df_cosine_sim
# Out:
#           doc1.txt  doc2.txt  doc3.txt  doc4.txt  doc5.txt  doc6.txt
# doc1.txt  1.000000  0.983454  0.229243  0.893466  0.893466  0.950443
# doc2.txt  0.983454  1.000000  0.299851  0.928313  0.928313  0.951575
# doc3.txt  0.229243  0.299851  1.000000  0.210041  0.210041  0.510652
# doc4.txt  0.893466  0.928313  0.210041  1.000000  1.000000  0.862778
# doc5.txt  0.893466  0.928313  0.210041  1.000000  1.000000  0.862778
# doc6.txt  0.950443  0.951575  0.510652  0.862778  0.862778  1.000000

# %% [markdown]
# Step 5: Compare Document Vectors and Cosine Similarity Matrix in Tabular Format

# %%
from IPython.core.display import display, HTML

# Convert the term frequencies dictionary to a DataFrame, using only document file names
df_term_freq = pd.DataFrame({doc.split('/')[-1]: tf for doc, tf in term_freq.items()}).T.fillna(0).astype(int)

# Convert the cosine similarity matrix to a DataFrame, using only document file names
df_cosine_sim = pd.DataFrame({doc1.split('/')[-1]: {doc2.split('/')[-1]: sim for doc2, sim in sims.items()}
                              for doc1, sims in cosine_sim_matrix.items()})

# Generate HTML tables for side-by-side display
table_term_freq = df_term_freq.to_html(classes='table table-condensed')
table_cosine_sim = df_cosine_sim.to_html(classes='table table-condensed')

# Display the tables side-by-side
display(HTML(f'<table><tr><td><h3>Document Vectors For Keywords</h3>{table_term_freq}</td><td><h3>Cosine Similarity Matrix</h3>{table_cosine_sim}</td></tr></table>'))
# Out:
# <table><tr><td><h3>Document Vectors For Keywords</h3><table border="1" class="dataframe table table-condensed">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>research</th>
#       <th>data</th>
#       <th>mining</th>
#       <th>analytics</th>
#       <th>machine learning</th>
#       <th>deep learning</th>
#       <th>data mining</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>doc1.txt</th>
#       <td>13</td>
#       <td>296</td>
#       <td>0</td>
#       <td>44</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>doc2.txt</th>
#       <td>31</td>
#       <td>264</td>
#       <td>21</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>doc3.txt</th>
#       <td>110</td>
#       <td>21</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>doc4.txt</th>
#       <td>27</td>
#       <td>575</td>
#       <td>280</td>
#       <td>19</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>doc5.txt</th>
#       <td>27</td>
#       <td>575</td>
#       <td>280</td>
#       <td>19</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>doc6.txt</th>
#       <td>40</td>
#       <td>107</td>
#       <td>5</td>
#       <td>23</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table></td><td><h3>Cosine Similarity Matrix</h3><table border="1" class="dataframe table table-condensed">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>doc1.txt</th>
#       <th>doc2.txt</th>
#       <th>doc3.txt</th>
#       <th>doc4.txt</th>
#       <th>doc5.txt</th>
#       <th>doc6.txt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>doc1.txt</th>
#       <td>1.000000</td>
#       <td>0.983454</td>
#       <td>0.229243</td>
#       <td>0.893466</td>
#       <td>0.893466</td>
#       <td>0.950443</td>
#     </tr>
#     <tr>
#       <th>doc2.txt</th>
#       <td>0.983454</td>
#       <td>1.000000</td>
#       <td>0.299851</td>
#       <td>0.928313</td>
#       <td>0.928313</td>
#       <td>0.951575</td>
#     </tr>
#     <tr>
#       <th>doc3.txt</th>
#       <td>0.229243</td>
#       <td>0.299851</td>
#       <td>1.000000</td>
#       <td>0.210041</td>
#       <td>0.210041</td>
#       <td>0.510652</td>
#     </tr>
#     <tr>
#       <th>doc4.txt</th>
#       <td>0.893466</td>
#       <td>0.928313</td>
#       <td>0.210041</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.862778</td>
#     </tr>
#     <tr>
#       <th>doc5.txt</th>
#       <td>0.893466</td>
#       <td>0.928313</td>
#       <td>0.210041</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.862778</td>
#     </tr>
#     <tr>
#       <th>doc6.txt</th>
#       <td>0.950443</td>
#       <td>0.951575</td>
#       <td>0.510652</td>
#       <td>0.862778</td>
#       <td>0.862778</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table></td></tr></table>

# %% [markdown]
# ### Part3: Analysis and Discussion of Problems
#
#
#
# # 1.   Discuss briefly about your topic analysis with your cosine similarity matrix focusing on that:  Whether each value (in Cosine Sim) of each pair of any two docs indicate the similarity correctly?
#  -->The cosine similarity value quantifies how similar two documents are based on their content. Values closer to 1 indicate higher similarity, while values closer to 0 indicate lower similarity. By examining the matrix, we can confirm if the expected similar documents have values near 1.
# •	Diagonal Values: These are 1, as expected, since a document is perfectly similar to itself.
# •	Doc4 and Doc5: This pair has a value of 1, indicating they are identical in terms of the 7 given topics.
# •	Other Pairs: Values between 0 and 1 indicate varying levels of similarity.
# Thus, each value in the cosine similarity matrix accurately reflects the similarity between document pairs.
#
# # 2.   Which 2 docs are most similar in terms of 7 given topics?
# -->Based on the generated cosine similarity matrix, doc4 and doc5 are the most similar in terms of the 7 given topics, as they have a cosine similarity value of 1, indicating they are identical regarding these topics.
#
# # 3.  The Topics of Doc6 is similar to the Topics of Doc 4 and 5?
#  Explain Why or Why Not in terms of 7 TFs? If not, what are the reasons?
#
#  -->The similarity between Doc6 and Doc4 is 0.844702. The similarity between Doc6 and Doc5 is 0.844702.
# Considering that the highest possible similarity score is 1 (indicating identical documents), the values of 0.844702 suggest that Doc6 is quite similar but not identical to both Doc4 and Doc5.
# However, the value 1 between Doc4 and Doc5 indicates they are essentially identical in terms of the seven topics.
# Now, in the context of Term Frequencies (TFs):
# Similarity: The similarity scores indicate that Doc6 has many of the same topics in common with Doc4 and Doc5. In other words, many of the 7 given topics appear with similar frequencies in Doc6 as they do in Doc4 and Doc5.
# Difference: The reason the similarity is not 1 (as with Doc4 and Doc5) suggests there are some differences in the term frequencies of the 7 topics. It could be due to slight variations in how often those topics appear, or perhaps one or more of the topics appear in Doc6 with a frequency that is notably different from Doc4 and Doc5.
# Reasons: Depth of Content: Doc6 might delve deeper into one or a few of the 7 topics than Doc4 and Doc5, leading to higher or lower term frequencies for those topics.Inclusion of Additional Content: There might be additional content or topics in Doc6 that could influence the term frequencies of the seven given topics.
# Different Context: The context or the way the topics are discussed in Doc6 might differ from Doc4 and Doc5, influencing the term frequencies.
# In conclusion, while Doc6 is similar to Doc4 and Doc5 in terms of the 7 topics, they are not identical. The differences in term frequencies for the given topics could be due to variations in content depth, context, or the inclusion of additional topics.
